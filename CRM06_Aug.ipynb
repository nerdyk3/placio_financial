# %%
import networkx as nx #Graphical persentation of unshorted data
import numpy as np #calculation lib
import pandas as pd #data Shoting Lib eg:series
import matplotlib.pyplot as mlt #for plot the data 
mlt.style.use('fivethirtyeight')
import seaborn as sns #statical data vertualisation 
import plotly.offline as py #plotly is a data_virtualisation 
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls

#check_out and ls will help in the to show files and folders

from subprocess import check_output
print(check_output(["ls"]).decode("utf8"))
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# 01_Aug_HMS_F.ipynb
# 02_Aug_HMS_F.ipynb
# 03_Aug_HMS_F.ipynb
# 04_Aug_HMS_F.ipynb
# 05_Aug_HMS_F.ipynb
# 06_Aug_HMS_F.ipynb
# col
# collect_and_due_amount_20180701_to_20180723.png
# converted_3_aug.ipynb
# CRM01_Aug.ipynb
# CRM02_Aug.ipynb
# CRM03_Aug.ipynb
# CRM04_Aug.ipynb
# CRM05_Aug.ipynb
# CRM06_Aug.ipynb
# csv
# due_and_collect_amount Graph.png
# FeeReport-2018-07-25 06_05_42.csv
# hms_db.sql
# july
# kk
# modes_tenants_until_21072018.png
# Paid_Pending.png
# PF009_2_may.png
# PF009_may.png
# README.md
# status_20180701_to_20180723.png
# table.html
# test.csv
# Untitled.ipynb

# %%
CRM30_ = pd.read_csv("csv/CRM05_Aug.csv")
CRM30_
# Out:
#                              Property Name Property visit date  \
# 0                                 GR Homes           06-Aug-18
# 1                                      NaN           06-Aug-18
# 2                     Half Penny Residency           06-Aug-18
# 3                                      NaN           06-Aug-18
# 4                           Imperial Homez           06-Aug-18
# 5    Placio Crystal Homez(Dinesh property)           06-Aug-18
# 6   Placio Exotic Living(BR accommodation)           06-Aug-18
# 7                                      NaN           06-Aug-18
# 8                                      NaN           06-Aug-18
# 9                        Placio Nightangle           06-Aug-18
# 10                                     NaN           06-Aug-18
# 11                                     NaN           06-Aug-18
# 12                   Placio Oasis 1( Boys)           06-Aug-18
# 13                   Placio Orchid (Girls)           06-Aug-18
# 14                        Placio Salvina 1           06-Aug-18
# 15                                     NaN           06-Aug-18
# 16                                     NaN           06-Aug-18
# 17                  Prestige Living (boys)           06-Aug-18
# 18                                     NaN           06-Aug-18
# 19                                     NaN           06-Aug-18
# 20                                     NaN           06-Aug-18
# 21                                RG Niwas           06-Aug-18
# 22                                     NaN           06-Aug-18
#
#          Contact Name        Mobile                         Email  \
# 0          k p ranjan    9425140890    kpranjandhabouli@gmail.com
# 1      aastha jaiswal    9753325749        akshaybali80@gmail.com
# 2             abhinav    9837172294                           NaN
# 3        Yogesh Kumar    8571933484                           NaN
# 4              Gaurav    7976924736     gurushagrover04@gmail.com
# 5           Nidhi rai    9780484060   nidhirai.bathla@hotmail.com
# 6              Preeti  918552985808                           NaN
# 7              Aayush    7889244522                           NaN
# 8           Priyanshi    7351333828                           NaN
# 9            Himanshu    9131222354            hmahto92@gmail.com
# 10      Reggie Mathew    7593001125           reggbin99@gmail.com
# 11          Siddharth    8109586421    sid.maheshwari28@gmail.com
# 12          Sudhanshu    8318933149      Singhsid111.ss@gmail.com
# 13  Amit / 9215351351    7027401111           amitk8308@gmail.com
# 14     Anurag Chandra    9007853361     anuragchandra61@gmail.com
# 15            shanyou    8257061147                           NaN
# 16             Chetan    9643421577      Chetan.kedia11@gmail.com
# 17         aman Gupta    8168127922                           NaN
# 18              Gopal    9930834396          anishggarg@gmail.com
# 19            Arihant    9113778233        arihantara33@gmail.com
# 20           Abhishek    7700837729  Abhishekrajdan0786@gmail.com
# 21              umang  918510801010                           NaN
# 22            Prakhar  919935731111                           NaN
#
#         Lead Stage  Property Region      Property Area             Assigned to
# 0   visit schedule           Indore        Vijay Nagar  Ankita Lohani (Intern)
# 1   visit schedule           Indore        Vijay Nagar  Ankita Lohani (Intern)
# 2   visit schedule    Greater Noida     Knowledge Park              Princy CRM
# 3   visit schedule    Greater Noida     Knowledge Park          Uvais Khan CRM
# 4   visit schedule     South Campus         Khirki Ext          Uvais Khan CRM
# 5   visit schedule     South Campus        Masjid Moth      Abhishek Bhati CRM
# 6   visit schedule     South Campus  Hari Nagar Ashram          Uvais Khan CRM
# 7   visit schedule     South Campus  Hari Nagar Ashram       Himanshu Negi CRM
# 8   visit schedule     South Campus  Hari Nagar Ashram             Rahul Kumar
# 9   visit schedule           Indore        Vijay Nagar       Akshita Singh CRM
# 10  visit schedule           Indore        Vijay Nagar              Princy CRM
# 11  visit schedule           Indore        Vijay Nagar          Uvais Khan CRM
# 12  visit schedule  DU North Campus        Kamla Nagar       Himanshu Negi CRM
# 13  visit schedule  DU North Campus        Vijay Nagar       Akshita Singh CRM
# 14  visit schedule  DU North Campus        Vijay Nagar      Abhishek Bhati CRM
# 15  visit schedule  DU North Campus        Vijay Nagar              Princy CRM
# 16  visit schedule  DU North Campus        Vijay Nagar       Akshita Singh CRM
# 17  visit schedule            Noida             Raipur       Akshita Singh CRM
# 18  visit schedule            Noida             Raipur          Uvais Khan CRM
# 19  visit schedule            Noida             Raipur          Uvais Khan CRM
# 20  visit schedule            Noida             Raipur       Akshita Singh CRM
# 21  visit schedule      Laxmi Nagar        Laxmi Nagar      Abhishek Bhati CRM
# 22  visit schedule      Laxmi Nagar        Laxmi Nagar      Abhishek Bhati CRM

# %%
x = CRM30_['Property Region'].value_counts()
y = CRM30_['Property Region'].nunique()
print(x,"\n\nTotal Property Region:",y)
# Out:
# South Campus       5
# Indore             5
# DU North Campus    5
# Noida              4
# Greater Noida      2
# Laxmi Nagar        2
# Name: Property Region, dtype: int64
#
# Total Property Region: 6

# %%
x = CRM30_['Property Name'].value_counts()
y = CRM30_['Property Name'].nunique()
print(x,"\n\nTotal Property Name:",y)
# Out:
# GR Homes                                  1
# Placio Nightangle                         1
# Placio Exotic Living(BR accommodation)    1
# Half Penny Residency                      1
# Placio Salvina 1                          1
# Placio Orchid (Girls)                     1
# Prestige Living (boys)                    1
# RG Niwas                                  1
# Placio Crystal Homez(Dinesh property)     1
# Placio Oasis 1( Boys)                     1
# Imperial Homez                            1
# Name: Property Name, dtype: int64
#
# Total Property Name: 11

# %%
x = CRM30_['Email'].value_counts()
y = CRM30_['Email'].nunique()
print(x,"\n\nTotal Email:",y)
# Out:
# kpranjandhabouli@gmail.com      1
# Chetan.kedia11@gmail.com        1
# hmahto92@gmail.com              1
# amitk8308@gmail.com             1
# reggbin99@gmail.com             1
# Singhsid111.ss@gmail.com        1
# Abhishekrajdan0786@gmail.com    1
# arihantara33@gmail.com          1
# gurushagrover04@gmail.com       1
# anishggarg@gmail.com            1
# anuragchandra61@gmail.com       1
# akshaybali80@gmail.com          1
# nidhirai.bathla@hotmail.com     1
# sid.maheshwari28@gmail.com      1
# Name: Email, dtype: int64
#
# Total Email: 14

# %%
CRM30_['Assigned to'].value_counts()
# Out:
# Uvais Khan CRM            6
# Akshita Singh CRM         5
# Abhishek Bhati CRM        4
# Princy CRM                3
# Himanshu Negi CRM         2
# Ankita Lohani (Intern)    2
# Rahul Kumar               1
# Name: Assigned to, dtype: int64

# %%
mlt.subplots(figsize=(15,9))
sns.countplot(x=CRM30_['Property Region'], hue= CRM30_['Property Region'], data = CRM30_).set_title("CRM report 31072018 Property_Region Wise")
mlt.show()

# %%
mlt.subplots(figsize=(30,9))
sns.countplot(x=CRM30_['Assigned to'], hue= CRM30_['Assigned to'], data = CRM30_).set_title("CRM report 31072018 Assigned to")
mlt.show()

# %%
mlt.subplots(figsize=(30,9))
sns.countplot(x=CRM30_['Assigned to'], hue= CRM30_['Property Region'], data = CRM30_).set_title("CRM report 29072018 Assigned to")
mlt.show()
