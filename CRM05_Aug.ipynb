# %%
import networkx as nx #Graphical persentation of unshorted data
import numpy as np #calculation lib
import pandas as pd #data Shoting Lib eg:series
import matplotlib.pyplot as mlt #for plot the data 
mlt.style.use('fivethirtyeight')
import seaborn as sns #statical data vertualisation 
import plotly.offline as py #plotly is a data_virtualisation 
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls

#check_out and ls will help in the to show files and folders

from subprocess import check_output
print(check_output(["ls"]).decode("utf8"))
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# 01_Aug_HMS_F.ipynb
# 02_Aug_HMS_F.ipynb
# 03_Aug_HMS_F.ipynb
# 04_Aug_HMS_F.ipynb
# 05_Aug_HMS_F.ipynb
# 06_Aug_HMS_F.ipynb
# col
# collect_and_due_amount_20180701_to_20180723.png
# converted_3_aug.ipynb
# CRM01_Aug.ipynb
# CRM02_Aug.ipynb
# CRM03_Aug.ipynb
# CRM04_Aug.ipynb
# CRM05_Aug.ipynb
# CRM06_Aug.ipynb
# csv
# due_and_collect_amount Graph.png
# FeeReport-2018-07-25 06_05_42.csv
# hms_db.sql
# july
# kk
# modes_tenants_until_21072018.png
# Paid_Pending.png
# PF009_2_may.png
# PF009_may.png
# README.md
# status_20180701_to_20180723.png
# table.html
# test.csv
# Untitled.ipynb

# %%
CRM30_ = pd.read_csv("csv/CRM06_Aug.csv")
CRM30_
# Out:
#                              Property Name Property visit date  \
# 0                               Angel Town           07-Aug-18
# 1                                 GR Homes           07-Aug-18
# 2                                      NaN           07-Aug-18
# 3                     Half Penny Residency           07-Aug-18
# 4                                      NaN           07-Aug-18
# 5                                      NaN           07-Aug-18
# 6                                      NaN           07-Aug-18
# 7                                      NaN           07-Aug-18
# 8                                      NaN           07-Aug-18
# 9                                      NaN           07-Aug-18
# 10                                     NaN           07-Aug-18
# 11            Placio Ashoka Inn(Nirmal PG)           07-Aug-18
# 12  Placio Exotic Living(BR accommodation)           07-Aug-18
# 13                             Placio Lily           07-Aug-18
# 14                       Placio Nightangle           07-Aug-18
# 15                                     NaN           07-Aug-18
# 16                                     NaN           07-Aug-18
# 17                                     NaN           07-Aug-18
# 18        Placio Pride Stay(Jeetu PG) Boys           07-Aug-18
# 19                                     NaN           07-Aug-18
# 20                        Placio Salvina 1           07-Aug-18
# 21                  Prestige Living (boys)           07-Aug-18
# 22                                RG Niwas           07-Aug-18
# 23                                     NaN           07-Aug-18
# 24                                     NaN           07-Aug-18
# 25                                     NaN           07-Aug-18
# 26                                     NaN           07-Aug-18
# 27                                   Venus           07-Aug-18
#
#                 Contact Name        Mobile                           Email  \
# 0   Dharmendra  / 8447952853  919870301637                             NaN
# 1                  rajnandni    7984657107     rajnandini11bhati@gmail.com
# 2                   Priyanka    9582774336    priyankasingh20047@gmail.com
# 3                      Sunny    7319884957                             NaN
# 4               Nikhil singh    8090302377            nikhil7971@gmail.com
# 5                     Piyush  919354665549                             NaN
# 6             Shubham Maurya    9716068026     shubhammaurya1821@gmail.com
# 7                       Amit  919837820224                             NaN
# 8                   Amritesh  918299207981                             NaN
# 9               Pritam Kumar  919710660756                             NaN
# 10                Atif nawaz    9838892111            ahmadklm38@gmail.com
# 11              Praman Gupta  917905428406                             NaN
# 12                    Daulat    9772203516      daulatsingkavia@g.mail.com
# 13                  Niharika    9102856633     nivedita.singh004@gmail.com
# 17      Uvais Khan CRM
# 18   Himanshu Negi CRM
# 19      Uvais Khan CRM
# 20          Princy CRM
# 21  Abhishek Bhati CRM
# 22          Princy CRM
# 23   Akshita Singh CRM
# 24   Akshita Singh CRM
# 25       Pradeep Chand
# 26   Akshita Singh CRM
# 27  Abhishek Bhati CRM

# %%
x = CRM30_['Property Region'].value_counts()
y = CRM30_['Property Region'].nunique()
print(x,"\n\nTotal Property Region:",y)
# Out:
# Greater Noida      8
# Laxmi Nagar        6
# Indore             6
# South Campus       4
# Noida              2
# DU North Campus    2
# Name: Property Region, dtype: int64
#
# Total Property Region: 6

# %%
x = CRM30_['Property Name'].value_counts()
y = CRM30_['Property Name'].nunique()
print(x,"\n\nTotal Property Name:",y)
# Out:
# Venus                                     1
# RG Niwas                                  1
# Placio Salvina 1                          1
# Placio Exotic Living(BR accommodation)    1
# Placio Nightangle                         1
# Half Penny Residency                      1
# GR Homes                                  1
# Angel Town                                1
# Placio Pride Stay(Jeetu PG) Boys          1
# Placio Lily                               1
# Prestige Living (boys)                    1
# Placio Ashoka Inn(Nirmal PG)              1
# Name: Property Name, dtype: int64
#
# Total Property Name: 12

# %%
x = CRM30_['Email'].value_counts()
y = CRM30_['Email'].nunique()
print(x,"\n\nTotal Email:",y)
# Out:
# 09manjeet.jagdev@gmail.com        1
# nikhil7971@gmail.com              1
# ahmadklm38@gmail.com              1
# aniket2646@gmail.com              1
# rajnandini11bhati@gmail.com       1
# shubhammaurya1821@gmail.com       1
# priyankasingh20047@gmail.com      1
# daulatsingkavia@g.mail.com        1
# choudharysiddharth04@gmail.com    1
# jadonsantosh123456@gmail.com      1
# rahulpatel.kt123@gmail.com        1
# rks030799@gmail.com               1
# aditisagyan@gmail.com             1
# nivedita.singh004@gmail.com       1
# Raisatyam204@gmail.com            1
# Name: Email, dtype: int64
#
# Total Email: 15

# %%
CRM30_['Assigned to'].value_counts()
# Out:
# Akshita Singh CRM     10
# Himanshu Negi CRM      6
# Abhishek Bhati CRM     4
# Princy CRM             3
# Uvais Khan CRM         3
# Pradeep Chand          1
# Rajni Bhola            1
# Name: Assigned to, dtype: int64

# %%
mlt.subplots(figsize=(15,9))
sns.countplot(x=CRM30_['Property Region'], hue= CRM30_['Property Region'], data = CRM30_).set_title("CRM report 31072018 Property_Region Wise")
mlt.show()

# %%
mlt.subplots(figsize=(30,9))
sns.countplot(x=CRM30_['Assigned to'], hue= CRM30_['Assigned to'], data = CRM30_).set_title("CRM report 31072018 Assigned to")
mlt.show()

# %%
mlt.subplots(figsize=(30,9))
sns.countplot(x=CRM30_['Assigned to'], hue= CRM30_['Property Region'], data = CRM30_).set_title("CRM report 29072018 Assigned to")
mlt.show()
