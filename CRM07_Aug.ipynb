# %%
import networkx as nx #Graphical persentation of unshorted data
import numpy as np #calculation lib
import pandas as pd #data Shoting Lib eg:series
import matplotlib.pyplot as mlt #for plot the data 
mlt.style.use('fivethirtyeight')
import seaborn as sns #statical data vertualisation 
import plotly.offline as py #plotly is a data_virtualisation 
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls

#check_out and ls will help in the to show files and folders

from subprocess import check_output
print(check_output(["ls"]).decode("utf8"))
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# 01_Aug_HMS_F.ipynb
# 02_Aug_HMS_F.ipynb
# 03_Aug_HMS_F.ipynb
# 04_Aug_HMS_F.ipynb
# 05_Aug_HMS_F.ipynb
# 06_Aug_HMS_F.ipynb
# 07_Aug_HMS_F.ipynb
# col
# collect_and_due_amount_20180701_to_20180723.png
# converted_3_aug.ipynb
# CRM01_Aug.ipynb
# CRM02_Aug.ipynb
# CRM03_Aug.ipynb
# CRM04_Aug.ipynb
# CRM05_Aug.ipynb
# CRM06_Aug.ipynb
# CRM07_Aug.ipynb
# csv
# due_and_collect_amount Graph.png
# FeeReport-2018-07-25 06_05_42.csv
# hms_db.sql
# july
# kk
# modes_tenants_until_21072018.png
# online_6_aug.ipynb
# online_7_aug.ipynb
# Paid_Pending.png
# PF009_2_may.png
# PF009_may.png
# README.md
# status_20180701_to_20180723.png
# table.html
# test.csv
# Untitled.ipynb

# %%
CRM30_ = pd.read_csv("csv/CRM07_Aug.csv")
CRM30_
# Out:
#                              Property Name Property visit date  \
# 0                                      NaN           08-Aug-18
# 1                                      NaN           08-Aug-18
# 2                             Admire Homes           08-Aug-18
# 3                                 GR Homes           08-Aug-18
# 4                     Half Penny Residency           08-Aug-18
# 5                                      NaN           08-Aug-18
# 6                 Placio Angel\'s Paradise           08-Aug-18
# 7   Placio Exotic Living(BR accommodation)           08-Aug-18
# 8                                      NaN           08-Aug-18
# 9                        Placio Nightangle           08-Aug-18
# 10                                     NaN           08-Aug-18
# 11                         Placio Princess           08-Aug-18
# 12                  Prestige Living (boys)           08-Aug-18
# 13                                     NaN           08-Aug-18
# 14                                     NaN           08-Aug-18
# 15                                RG Niwas           08-Aug-18
# 16                                     NaN           08-Aug-18
# 17                                     NaN           08-Aug-18
# 18                                     NaN           08-Aug-18
# 19                                   Venus           08-Aug-18
#
#       Contact Name        Mobile                        Email      Lead Stage  \
# 0           SURBHI    9639504168     surbhiarora169@gmail.com  visit schedule
# 1          Shubham  917999369065  shubhampandey7777@gmail.com  visit schedule
# 2          Mandeep    9891402516     mittal_mandeep@yahoo.com  visit schedule
# 3   Priyal Mahajan  917583077745                          NaN  visit schedule
# 4            Sunny    7319884957                          NaN  visit schedule
# 5           Piyush  919354665549                          NaN  visit schedule
# 6         Shraddha    9424427390                          NaN  visit schedule
# 7            ASHOK    9418065952      kaundal.ashok@yahoo.com  visit schedule
# 8            Rajat  918076473764     rajatrawat7291@gmail.com  visit schedule
# 9            Manoj  918839415608                          NaN  visit schedule
# 10          Sanjay    9653196122                          NaN  visit schedule
# 11    Aditi Mishra  916386377347                          NaN  visit schedule
# 12           neelu    8053541145                          NaN  visit schedule
# 13           Ayush    7906979108                          NaN  visit schedule
# 14        Lakshaya    9803040304                          NaN  visit schedule
# 15          pankaj    9560782721        pankajaskme@gmail.com  visit schedule
# 16  Priyanka gupta  917677473869                          NaN  visit schedule
# 17           Aditi  919742080697                          NaN  visit schedule
# 18         Suraiya  917229913873                          NaN  visit schedule
# 19           Arzoo    9319903653    arzoochhabra999@gmail.com  visit schedule
#
#    Property Region      Property Area         Assigned to
# 0              NaN                NaN          Princy CRM
# 1              NaN                NaN  Abhishek Bhati CRM
# 2            Noida             Raipur          Princy CRM
# 3           Indore        Vijay Nagar   Himanshu Negi CRM
# 4    Greater Noida     Knowledge Park   Himanshu Negi CRM
# 5    Greater Noida     Knowledge Park   Himanshu Negi CRM
# 6              NaN                NaN   Himanshu Negi CRM
# 7     South Campus  Hari Nagar Ashram          Princy CRM
# 8     South Campus  Hari Nagar Ashram   Himanshu Negi CRM
# 9           Indore        Vijay Nagar   Himanshu Negi CRM
# 10          Indore        Vijay Nagar   Himanshu Negi CRM
# 11         Lucknow            Lucknow   Akshita Singh CRM
# 12           Noida             Raipur   Himanshu Negi CRM
# 13           Noida             Raipur          Princy CRM
# 14           Noida             Raipur  Abhishek Bhati CRM
# 15     Laxmi Nagar        Laxmi Nagar  Abhishek Bhati CRM
# 16     Laxmi Nagar        Laxmi Nagar   Akshita Singh CRM
# 17     Laxmi Nagar        Laxmi Nagar   Akshita Singh CRM
# 18     Laxmi Nagar        Laxmi Nagar  Abhishek Bhati CRM
# 19           Noida             Raipur  Abhishek Bhati CRM

# %%
x = CRM30_['Property Region'].value_counts()
y = CRM30_['Property Region'].nunique()
print(x,"\n\nTotal Property Region:",y)
# Out:
# Noida            5
# Laxmi Nagar      4
# Indore           3
# Greater Noida    2
# South Campus     2
# Lucknow          1
# Name: Property Region, dtype: int64
#
# Total Property Region: 6

# %%
x = CRM30_['Property Name'].value_counts()
y = CRM30_['Property Name'].nunique()
print(x,"\n\nTotal Property Name:",y)
# Out:
# Placio Princess                           1
# Placio Nightangle                         1
# Placio Exotic Living(BR accommodation)    1
# Venus                                     1
# RG Niwas                                  1
# Half Penny Residency                      1
# Placio Angel\'s Paradise                  1
# GR Homes                                  1
# Prestige Living (boys)                    1
# Admire Homes                              1
# Name: Property Name, dtype: int64
#
# Total Property Name: 10

# %%
x = CRM30_['Email'].value_counts()
y = CRM30_['Email'].nunique()
print(x,"\n\nTotal Email:",y)
# Out:
# pankajaskme@gmail.com          1
# shubhampandey7777@gmail.com    1
# surbhiarora169@gmail.com       1
# kaundal.ashok@yahoo.com        1
# rajatrawat7291@gmail.com       1
# arzoochhabra999@gmail.com      1
# mittal_mandeep@yahoo.com       1
# Name: Email, dtype: int64
#
# Total Email: 7

# %%
CRM30_['Assigned to'].value_counts()
# Out:
# Himanshu Negi CRM     8
# Abhishek Bhati CRM    5
# Princy CRM            4
# Akshita Singh CRM     3
# Name: Assigned to, dtype: int64

# %%
mlt.subplots(figsize=(15,9))
sns.countplot(x=CRM30_['Property Region'], hue= CRM30_['Property Region'], data = CRM30_).set_title("CRM report 31072018 Property_Region Wise")
mlt.show()

# %%
mlt.subplots(figsize=(30,9))
sns.countplot(x=CRM30_['Assigned to'], hue= CRM30_['Assigned to'], data = CRM30_).set_title("CRM report 31072018 Assigned to")
mlt.show()

# %%
mlt.subplots(figsize=(30,9))
sns.countplot(x=CRM30_['Assigned to'], hue= CRM30_['Property Region'], data = CRM30_).set_title("CRM report 29072018 Assigned to")
mlt.show()
