# %%
import networkx as nx #Graphical persentation of unshorted data
import numpy as np #calculation lib
import pandas as pd #data Shoting Lib eg:series
import matplotlib.pyplot as mlt #for plot the data 
mlt.style.use('fivethirtyeight')
import seaborn as sns #statical data vertualisation 
import plotly.offline as py #plotly is a data_virtualisation 
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls

#check_out and ls will help in the to show files and folders

from subprocess import check_output
print(check_output(["ls"]).decode("utf8"))
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# 01_Aug_HMS_F.ipynb
# 02_Aug_HMS_F.ipynb
# col
# collect_and_due_amount_20180701_to_20180723.png
# CRM01_Aug.ipynb
# CRM02_Aug.ipynb
# csv
# due_and_collect_amount Graph.png
# FeeReport-2018-07-25 06_05_42.csv
# hms_db.sql
# july
# kk
# modes_tenants_until_21072018.png
# Paid_Pending.png
# PF009_2_may.png
# PF009_may.png
# README.md
# status_20180701_to_20180723.png
# table.html
# test.csv
# Untitled.ipynb

# %%
CRM30_ = pd.read_csv("csv/CRM02_Aug.csv")
CRM30_
# Out:
#                              Property Name Property visit date  \
# 0                                      NaN           02-Aug-18
# 1                                      NaN           02-Aug-18
# 2                                      NaN           02-Aug-18
# 3                             Admire Homes           02-Aug-18
# 4                                      NaN           02-Aug-18
# 5                            Admire Homes2           02-Aug-18
# 6                            Elite Homes 2           02-Aug-18
# 7                                 GR Homes           02-Aug-18
# 8                                      NaN           02-Aug-18
# 9                     Half Penny Residency           02-Aug-18
# 10                                     NaN           02-Aug-18
# 11                                     NaN           02-Aug-18
# 12                          Imperial Homez           02-Aug-18
# 13                                     NaN           02-Aug-18
# 14                Placio Angel\'s Paradise           02-Aug-18
# 15  Placio Exotic Living(BR accommodation)           02-Aug-18
# 16                             Placio Lily           02-Aug-18
# 17                   Placio Oasis 1( Boys)           02-Aug-18
# 18                  Placio Oasis 3 (Girls)           02-Aug-18
# 19                 Placio Precious( Girls)           02-Aug-18
# 20                        Placio Salvina 1           02-Aug-18
# 21                         Placio Vinayaka           02-Aug-18
# 22                                     NaN           02-Aug-18
# 23                                RG Niwas           02-Aug-18
# 24                                     NaN           02-Aug-18
# 25                           Shresth Homes           02-Aug-18
#
#         Contact Name        Mobile                                  Email  \
# 0              Suraj    8299178203                                    NaN
# 1            Shishil  919027125842                                    NaN
# 2     Sanjay Agarwal    8447093603                                    NaN
# 3             chirag    9560561977                                    NaN
# 4             Govind    8178695199                                    NaN
# 5             deepak    7004039498                                    NaN
# 6   VIJAY KUMAR OJHA    9958848955                 vkojha2011@hotmail.com
# 7              aarti  917905002513               aartigautam788@gmail.com
# 8             Nikita    9340538308                                    NaN
# 9             Akarsh    8178288271                                    NaN
# 17        Himanshu Negi CRM
# 18        Himanshu Negi CRM
# 19        Himanshu Negi CRM
# 20        Himanshu Negi CRM
# 21        Himanshu Negi CRM
# 22        Akshita Singh CRM
# 23       Abhishek Bhati CRM
# 24        Akshita Singh CRM
# 25               Princy CRM

# %%
x = CRM30_['Property Region'].value_counts()
y = CRM30_['Property Region'].nunique()
print(x,"\n\nTotal Property Region:",y)
# Out:
# Noida              5
# Indore             4
# DU North Campus    4
# Greater Noida      3
# South Campus       3
# Laxmi Nagar        2
# Lucknow            1
# Name: Property Region, dtype: int64
#
# Total Property Region: 7

# %%
x = CRM30_['Property Name'].value_counts()
y = CRM30_['Property Name'].nunique()
print(x,"\n\nTotal Property Name:",y)
# Out:
# Shresth Homes                             1
# Placio Oasis 3 (Girls)                    1
# Placio Oasis 1( Boys)                     1
# Placio Salvina 1                          1
# RG Niwas                                  1
# Half Penny Residency                      1
# Placio Angel\'s Paradise                  1
# Placio Precious( Girls)                   1
# Elite Homes 2                             1
# GR Homes                                  1
# Imperial Homez                            1
# Placio Lily                               1
# Placio Exotic Living(BR accommodation)    1
# Admire Homes                              1
# Placio Vinayaka                           1
# Admire Homes2                             1
# Name: Property Name, dtype: int64
#
# Total Property Name: 16

# %%
x = CRM30_['Email'].value_counts()
y = CRM30_['Email'].nunique()
print(x,"\n\nTotal Email:",y)
# Out:
# roopes_2006@rediffmail.com               1
# vkojha2011@hotmail.com                   1
# rishi.sharma@sterlingpupublishers.com    1
# amitsehlangia5@gmail.com                 1
# uddeshpradhan30@gmail.com                1
# aartigautam788@gmail.com                 1
# nupurerchonde@gmail.com                  1
# ayushisharma89angel@gmail.com            1
# varun.baiswar88@gmail.com                1
# yogeshgoswami2505@gmail.com              1
# saurav21singh@gmail.com                  1
# Name: Email, dtype: int64
#
# Total Email: 11

# %%
CRM30_['Assigned to'].value_counts()
# Out:
# Himanshu Negi CRM          13
# Akshita Singh CRM           5
# Abhishek Bhati CRM          2
# Ankita Lohani (Intern)      1
# Neha Morya (Intern)         1
# Princy CRM                  1
# Uvais Khan CRM              1
# Komal Arya (Intern)         1
# Devanshi Gupta (Intern)     1
# Name: Assigned to, dtype: int64

# %%
mlt.subplots(figsize=(15,9))
sns.countplot(x=CRM30_['Property Region'], hue= CRM30_['Property Region'], data = CRM30_).set_title("CRM report 31072018 Property_Region Wise")
mlt.plot()
# Out:
# []

# %%
mlt.subplots(figsize=(30,9))
sns.countplot(x=CRM30_['Assigned to'], hue= CRM30_['Assigned to'], data = CRM30_).set_title("CRM report 31072018 Assigned to")
mlt.plot()
# Out:
# []
