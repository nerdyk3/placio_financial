# %%
import networkx as nx #Graphical persentation of unshorted data
import numpy as np #calculation lib
import pandas as pd #data Shoting Lib eg:series
import matplotlib.pyplot as mlt #for plot the data 
mlt.style.use('fivethirtyeight')
import seaborn as sns #statical data vertualisation 
import plotly.offline as py #plotly is a data_virtualisation 
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls

#check_out and ls will help in the to show files and folders

from subprocess import check_output
print(check_output(["ls"]).decode("utf8"))
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# 26_HMS_F.ipynb
# 27_HMS_F.ipynb
# 28_HMS_F.ipynb
# 29_HMS_F.ipynb
# col
# collect_and_due_amount_20180701_to_20180723.png
# cratio_25_7.csv
# cratio_25_7.ipynb
# CRM27_.ipynb
# CRM28_.ipynb
# CRM29_.ipynb
# CRM30_.ipynb
# csv
# due_and_collect_amount Graph.png
# FeeReport-2018-07-25 06_05_42.csv
# hms_db.sql
# kk
# modes_tenants_until_21072018.png
# month_date_range.ipynb
# monthly_property_Report_test.ipynb
# month_report_notebook.ipynb
# Paid_Pending.png
# persent_mode_report.ipynb
# PF009_2_may.png
# PF009_may.png
# README.md
# report _25_07_2018.ipynb
# status_20180701_to_20180723.png
# table.html
# Untitled.ipynb

# %%
CRM29_= pd.read_csv("csv/CRM30_.csv")
CRM29_
# Out:
#                              Property Name Property visit date  \
# 0                                      NaN           30-Jul-18
# 1                                      NaN           30-Jul-18
# 2                                      NaN           30-Jul-18
# 3                                      NaN           30-Jul-18
# 4                                      NaN           30-Jul-18
# 5                                      NaN           30-Jul-18
# 6                                      NaN           30-Jul-18
# 7                                      NaN           30-Jul-18
# 8                                      NaN           30-Jul-18
# 9                                      NaN           30-Jul-18
# 10                            Admire Homes           30-Jul-18
# 11                                     NaN           30-Jul-18
# 12                                     NaN           30-Jul-18
# 13                               Amy House           30-Jul-18
# ...

# %%
x = CRM29_['Property Region'].value_counts()
y = CRM29_['Property Region'].nunique()
print(x,"\n\nTotal Property Region:",y)
# Out:
# South Campus       13
# Noida              11
# Indore              9
# DU North Campus     4
# Greater Noida       4
# Laxmi Nagar         3
# Name: Property Region, dtype: int64
#
# Total Property Region: 6

# %%
x = CRM29_['Property Name'].value_counts()
y = CRM29_['Property Name'].nunique()
print(x,"\n\nTotal Property Name:",y)
# Out:
# Placio Ashoka Inn(Nirmal PG)              1
# Apollo                                    1
# Venus                                     1
# Elite Homes 2                             1
# Placio Crystal Homez(Dinesh property)     1
# Amy House                                 1
# JP House                                  1
# Divya Homes                               1
# Admire Homes                              1
# Home Care                                 1
# RG Niwas                                  1
# Placio Vinayaka                           1
# Placio Oasis 1( Boys)                     1
# Placio Lily                               1
# Placio Nightangle                         1
# Half Penny Residency                      1
# Imperial Homez                            1
# Placio Exotic Living(BR accommodation)    1
# GR Homes                                  1
# Name: Property Name, dtype: int64
#
# Total Property Name: 19

# %%
x = CRM29_['Email'].value_counts()
y = CRM29_['Email'].nunique()
print(x,"\n\nTotal Email:",y)
# Out:
# krmohak@gmail.com                   1
# pallaviprincess.kumari@gmail.com    1
# ptakaguddi.jhamru@gmail.com         1
# chandu231224@gmail.com              1
# shrivastavasumedh@gmail.com         1
# kk9990155557@gmail.com              1
# bhuvneshjindal11@gmail.com          1
# kpranjandhabouli@gmail.com          1
# sanjula25june@gmail.com             1
# brijeshpande4444@gmail.com          1
# guptaneha18jan@gmail.com            1
# twinklekataria888@gmail.com         1
# ayushman26021999@gmail.com          1
# ayushraj3905@gmail.com              1
# shreyanshmishra14799@gmail.com      1
# mayankdubey497@gmail.com            1
# mksingh192@yahoo.com                1
# ahmadsameer@lntecc.com              1
# naman912000@gmail.com               1
# Name: Email, dtype: int64
#
# Total Email: 19

# %%
CRM29_['Assigned to'].value_counts()
# Out:
# Himanshu Negi CRM          17
# Abhishek Bhati CRM          8
# Ankita Lohani (Intern)      4
# Uvais Khan CRM              4
# Komal Arya (Intern)         4
# Himanshu Joshi              3
# Kuldeep Chouhaan            2
# Shilpi Singh CRM            2
# Akshita Singh CRM           2
# Shobit Singh                1
# Rahul Kumar                 1
# Princy CRM                  1
# Devanshi Gupta (Intern)     1
# Neha Morya (Intern)         1
# Rakesh Mishra               1
# Ayushi Mishra               1
# Deoraj Kumar                1
# Name: Assigned to, dtype: int64

# %%
mlt.subplots(figsize=(15,9))
sns.countplot(x=CRM29_['Property Region'], hue= CRM29_['Property Region'], data = CRM29_).set_title("CRM report 29072018 Property_Region Wise")
mlt.plot()
# Out:
# []

# %%
mlt.subplots(figsize=(40,9))
sns.countplot(x=CRM29_['Assigned to'], hue= CRM29_['Assigned to'], data = CRM29_).set_title("CRM report 29072018 Assigned to")
mlt.plot()
# Out:
# []

# %%
mlt.subplots(figsize=(40,9))
sns.countplot(x=CRM29_['Assigned to'], hue= CRM29_['Property Region'], data = CRM29_).set_title("CRM report 29072018 Assigned to")
mlt.plot()
# Out:
# []
