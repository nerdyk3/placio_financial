# 46       Placio Home Care KO-11  2018PM0151084           NaN
#
#           Collected Amount Tenant Code              Tenant Name    Mode  \
# 0   TOTAL AMOUNT : 2459600           -                        -       -
# 1                    13600    18192445       OBEDENCE TINOTENDA  online
# 2                    39000   181901074              Ansh Khanna    cash
# 3                    39000   181901068       Harman singh Kamra    cash
# 4                    39000   181900964          Ramandeep Singh    cash
# 5                    39000   181900964          Ramandeep Singh    cash
# 6                    50000    18192087          Sahil Bharadwaj  online
# 7                    66000    18191682                Praveen R   paytm
# 8                    66000    18191682                Praveen R   paytm
# 9                    30000    18191682                Praveen R   paytm
# 10                   46000   181901176           Srinath Sundar  online
# 11                   50000   181901176           Srinath Sundar  online
# 12                   84000   181901392  Harsh Pratap Singh Rana  cheque
# 13                   84000   181901392  Harsh Pratap Singh Rana  cheque
# 14                   84000   181901392  Harsh Pratap Singh Rana  online
# 15                    5500    18192448             AKSHAY GUPTA    cash
# 16                   48000    18191992      Arka Ruchir Mahanta  cheque
# 17                   48000    18191992      Arka Ruchir Mahanta  cheque
# 18                   48000    18191992      Arka Ruchir Mahanta  cheque
# 19                   48000    18191992      Arka Ruchir Mahanta  cheque
# 20                   48000    18191992      Arka Ruchir Mahanta  cheque
# 21                   56000   181901634      Afros rezaur rahman    cash
# 22                   56000   181901634      Afros rezaur rahman    cash
# 23                   96000   181901178            Nirbhay Gupta  online
# 24                   72000   181901294     Yash Vardhan Agrawal  cheque
# 25                   72000   181901294     Yash Vardhan Agrawal  cheque
# 26                   64000    18192052            Naman agarwal    cash
# 27                   64000    18192052            Naman agarwal    cash
# 28                   64000    18192052            Naman agarwal    cash
# 29                    2500    18192185            VANSHIKA JAIN  online
# 30                   17500    18192185            VANSHIKA JAIN    cash
# 31                   13000   181901378          SANJEEV JAISWAL  online
# 32                   10500   181901378          SANJEEV JAISWAL    cash
# 33                  160000   181900215        Dipankar Pasricha    cash
# 34                   84000   181900191               Ayush soni  online
# 35                    5000   181900844      KRISHNA KUMAR PATEL    cash
# 36                    5000   181900844      KRISHNA KUMAR PATEL    cash
# 37                  108000   181901569           Akarsh Jaswani  online
# 38                  108000   181901569           Akarsh Jaswani  online
# 39                  108000    18191694               Toko Dopum  cheque
# 40                   40000    18192210      Ahmad Hammad Zubair    cash
# 41                   46500    18192081   Manvendra pratap singh    cash
# 42                   46500    18192081   Manvendra pratap singh    cash
# 43                   46500    18192081   Manvendra pratap singh  cheque
# 44                   46500    18192081   Manvendra pratap singh  cheque
# 45                   46500    18192081   Manvendra pratap singh  cheque
# 46                   46500    18192081   Manvendra pratap singh  cheque
#
#            Term        Date   Status
# 0             -           -        -
# 1       monthly  2018-08-03  pending
# 2     quarterly  2018-08-03  pending
# 3   half-yearly  2018-08-03  pending
# 4   half-yearly  2018-08-03  pending
# 5   half-yearly  2018-08-03  pending
# 6   half-yearly  2018-08-03  pending
# 7   half-yearly  2018-08-03  pending
# 8   half-yearly  2018-08-03  pending
# 9   half-yearly  2018-08-03  pending
# 10  half-yearly  2018-08-03  pending
# 11  half-yearly  2018-08-03  pending
# 12    quarterly  2018-08-03  pending
# 13    quarterly  2018-08-03  pending
# 14    quarterly  2018-08-03  pending
# 15       yearly  2018-08-03  pending
# 16    quarterly  2018-08-03  pending
# 17    quarterly  2018-08-03  pending
# 18    quarterly  2018-08-03  pending
# 19    quarterly  2018-08-03  pending
# 20    quarterly  2018-08-03  pending
# 21  half-yearly  2018-08-03  pending
# 22  half-yearly  2018-08-03  pending
# 23  half-yearly  2018-08-03  pending
# 24  half-yearly  2018-08-03  pending
# 25  half-yearly  2018-08-03  pending
# 26  half-yearly  2018-08-03  pending
# 27  half-yearly  2018-08-03  pending
# 28  half-yearly  2018-08-03  pending
# 29      monthly  2018-08-03  pending
# 30      monthly  2018-08-03  pending
# 31      monthly  2018-08-03  pending
# 32      monthly  2018-08-03  pending
# 33  half-yearly  2018-08-03  pending
# 34  half-yearly  2018-08-03  pending
# 35      monthly  2018-08-03  pending
# 36      monthly  2018-08-03  pending
# 37  half-yearly  2018-08-03  pending
# 38  half-yearly  2018-08-03  pending
# 39  half-yearly  2018-08-03  pending
# 40  half-yearly  2018-08-03  pending
# 41  half-yearly  2018-08-03  pending
# 42  half-yearly  2018-08-03  pending
# 43  half-yearly  2018-08-03  pending
# 44  half-yearly  2018-08-03  pending
# 45  half-yearly  2018-08-03  pending
# 46  half-yearly  2018-08-03  pending

# %%
D30_ = HMS30_.sort_values(by='Collected Amount' , ascending= False)
D30_
# Out:
#                   Property Name     Invoice ID        TXN ID  \
# 0                             -              -             -
# 23        Placio Home Care SL02  2018PM0181107           NaN
# 12        Placio Home Care SL02  2018PM0181119           NaN
# 34       Placio Home Care KO-11  2018PM0151096           NaN
# 14        Placio Home Care SL02  2018PM0181117          neft
# 13        Placio Home Care SL02  2018PM0181118           NaN
# 24        Placio Home Care SL02  2018PM0181106           NaN
# 25        Placio Home Care SL02  2018PM0181105           NaN
# 8         Placio Home Care SL02  2018PM0181123   19864782643
# 7         Placio Home Care SL02  2018PM0181124   19864782643
# 26       Placio Home Care KO-11  2018PM0151104           NaN
# 27       Placio Home Care KO-11  2018PM0151103           NaN
# 28       Placio Home Care KO-11  2018PM0151102           NaN
# 21        Placio Home Care SL02  2018PM0181109           NaN
# 22        Placio Home Care SL02  2018PM0181108           NaN
# 15       Placio Home Care KO-17  2018PM0171115           NaN
# 11        Placio Home Care SL02  2018PM0181120           NaN
# 6         Placio Home Care SL02  2018PM0181125           NaN
# 36            Placio AK Mansion  2018PMI031094           NaN
# 35            Placio AK Mansion  2018PMI031095           NaN
# 20        Placio Home Care SL02  2018PM0181110           NaN
# 19        Placio Home Care SL02  2018PM0181111           NaN
# 18        Placio Home Care SL02  2018PM0181112           NaN
# 17        Placio Home Care SL02  2018PM0181113           NaN
# 16        Placio Home Care SL02  2018PM0181114           NaN
# 41       Placio Home Care KO-11  2018PM0151089           NaN
# 42       Placio Home Care KO-11  2018PM0151088           NaN
# 43       Placio Home Care KO-11  2018PM0151087           NaN
# 44       Placio Home Care KO-11  2018PM0151086           NaN
# 9                    30000    18191682                Praveen R   paytm
# 29                    2500    18192185            VANSHIKA JAIN  online
# 30                   17500    18192185            VANSHIKA JAIN    cash
# 33                  160000   181900215        Dipankar Pasricha    cash
# 1                    13600    18192445       OBEDENCE TINOTENDA  online
# 31                   13000   181901378          SANJEEV JAISWAL  online
# 37                  108000   181901569           Akarsh Jaswani  online
# 38                  108000   181901569           Akarsh Jaswani  online
# 39                  108000    18191694               Toko Dopum  cheque
# 32                   10500   181901378          SANJEEV JAISWAL    cash
#
#            Term        Date   Status
# 0             -           -        -
# 23  half-yearly  2018-08-03  pending
# 12    quarterly  2018-08-03  pending
# 34  half-yearly  2018-08-03  pending
# 14    quarterly  2018-08-03  pending
# 13    quarterly  2018-08-03  pending
# 24  half-yearly  2018-08-03  pending
# 25  half-yearly  2018-08-03  pending
# 8   half-yearly  2018-08-03  pending
# 7   half-yearly  2018-08-03  pending
# 26  half-yearly  2018-08-03  pending
# 27  half-yearly  2018-08-03  pending
# 28  half-yearly  2018-08-03  pending
# 21  half-yearly  2018-08-03  pending
# 22  half-yearly  2018-08-03  pending
# 15       yearly  2018-08-03  pending
# 11  half-yearly  2018-08-03  pending
# 6   half-yearly  2018-08-03  pending
# 36      monthly  2018-08-03  pending
# 35      monthly  2018-08-03  pending
# 20    quarterly  2018-08-03  pending
# 19    quarterly  2018-08-03  pending
# 18    quarterly  2018-08-03  pending
# 17    quarterly  2018-08-03  pending
# 16    quarterly  2018-08-03  pending
# 41  half-yearly  2018-08-03  pending
# 42  half-yearly  2018-08-03  pending
# 43  half-yearly  2018-08-03  pending
# 44  half-yearly  2018-08-03  pending
# 45  half-yearly  2018-08-03  pending
# 46  half-yearly  2018-08-03  pending
# 10  half-yearly  2018-08-03  pending
# 40  half-yearly  2018-08-03  pending
# 3   half-yearly  2018-08-03  pending
# 5   half-yearly  2018-08-03  pending
# 4   half-yearly  2018-08-03  pending
# 2     quarterly  2018-08-03  pending
# 9   half-yearly  2018-08-03  pending
# 29      monthly  2018-08-03  pending
# 30      monthly  2018-08-03  pending
# 33  half-yearly  2018-08-03  pending
# 1       monthly  2018-08-03  pending
# 31      monthly  2018-08-03  pending
# 37  half-yearly  2018-08-03  pending
# 38  half-yearly  2018-08-03  pending
# 39  half-yearly  2018-08-03  pending
# 32      monthly  2018-08-03  pending

# %%
mlt.subplots(figsize=(10,7))
sns.countplot(x=D30_['Mode'],hue=D30_['Mode'], data=D30_).set_title("Tenant count Payment Mode wise")
#mlt.savefig('status_20180701_to_20180723.png')
mlt.show()

# %%
mlt.subplots(figsize=(20,9))
sns.countplot(x=D30_['Property Name'],hue=D30_['Property Name'], data=D30_).set_title("Tenant count property wise")
#mlt.savefig('status_20180701_to_20180723.png')
mlt.show()

# %%
mlt.subplots(figsize=(10,7))
sns.countplot(x=D30_['Mode'],hue=D30_['Term'], data=D30_).set_title("monthly and yearly count payment mode wise")
#mlt.savefig('status_20180701_to_20180723.png')
mlt.show()

# %%
mlt.subplots(figsize=(20,9))
sns.countplot(x=D30_['Property Name'],hue=D30_['Status'], data=D30_).set_title("status Property wise")
#mlt.savefig('status_20180701_to_20180723.png')
mlt.show()

# %%
mlt.subplots(figsize=(30,7))
sns.countplot(x=D30_['Tenant Code'],hue=D30_['Mode'], data=D30_).set_title("Payment Mode used buy tenant")
#mlt.savefig('status_20180701_to_20180723.png')
mlt.show()

# %%
mlt.subplots(figsize=(40,7))
sns.countplot(x=D30_['Tenant Code'],hue=D30_['Term'], data=D30_).set_title("Tenant term used")
#mlt.savefig('status_20180701_to_20180723.png')
mlt.show()
