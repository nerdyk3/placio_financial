# %%
import networkx as nx #Graphical persentation of unshorted data
import numpy as np #calculation lib
import pandas as pd #data Shoting Lib eg:series
import matplotlib.pyplot as mlt #for plot the data 
mlt.style.use('fivethirtyeight')
import seaborn as sns #statical data vertualisation 
import plotly.offline as py #plotly is a data_virtualisation 
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls

#check_out and ls will help in the to show files and folders

from subprocess import check_output
print(check_output(["ls"]).decode("utf8"))
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# 01_Aug_HMS_F.ipynb
# 02_Aug_HMS_F.ipynb
# 03_Aug_HMS_F.ipynb
# 04_Aug_HMS_F.ipynb
# 05_Aug_HMS_F.ipynb
# 06_Aug_HMS_F.ipynb
# col
# collect_and_due_amount_20180701_to_20180723.png
# converted_3_aug.ipynb
# CRM01_Aug.ipynb
# CRM02_Aug.ipynb
# CRM03_Aug.ipynb
# CRM04_Aug.ipynb
# CRM05_Aug.ipynb
# CRM06_Aug.ipynb
# csv
# due_and_collect_amount Graph.png
# FeeReport-2018-07-25 06_05_42.csv
# hms_db.sql
# july
# kk
# modes_tenants_until_21072018.png
# Paid_Pending.png
# PF009_2_may.png
# PF009_may.png
# README.md
# status_20180701_to_20180723.png
# table.html
# test.csv
# Untitled.ipynb

# %%
CRM30_ = pd.read_csv("csv/CRM04_Aug.csv")
CRM30_
# Out:
#                              Property Name Property visit date  \
# 0                                      NaN           05-Aug-18
# 1                                      NaN           05-Aug-18
# 2                                      NaN           05-Aug-18
# 3                             A.K. Mansion           05-Aug-18
# 4                               Angel Town           05-Aug-18
# 5                                      NaN           05-Aug-18
# 6                            Elite Homes 2           05-Aug-18
# 7                                      NaN           05-Aug-18
# 8                                 GR Homes           05-Aug-18
# 9                     Half Penny Residency           05-Aug-18
# 10                                     NaN           05-Aug-18
# 11                                     NaN           05-Aug-18
# 12                                     NaN           05-Aug-18
# 13                                     NaN           05-Aug-18
# ...

# %%
x = CRM30_['Property Region'].value_counts()
y = CRM30_['Property Region'].nunique()
print(x,"\n\nTotal Property Region:",y)
# Out:
# Greater Noida      7
# Laxmi Nagar        6
# Indore             6
# DU North Campus    6
# South Campus       5
# Noida              2
# Name: Property Region, dtype: int64
#
# Total Property Region: 6

# %%
x = CRM30_['Property Name'].value_counts()
y = CRM30_['Property Name'].nunique()
print(x,"\n\nTotal Property Name:",y)
# Out:
# Placio Birdhouse 1                        1
# Angel Town                                1
# Placio Lily                               1
# Placio Crystal Homez(Dinesh property)     1
# Placio Salvina 1                          1
# GR Homes                                  1
# RG Niwas                                  1
# Placio Vinayaka                           1
# Placio Exotic Living(BR accommodation)    1
# Placio Ashoka Inn(Nirmal PG)              1
# Placio Nightangle                         1
# Elite Homes 2                             1
# Half Penny Residency                      1
# A.K. Mansion                              1
# Imperial Homez                            1
# Name: Property Name, dtype: int64
#
# Total Property Name: 15

# %%
x = CRM30_['Email'].value_counts()
y = CRM30_['Email'].nunique()
print(x,"\n\nTotal Email:",y)
# Out:
# vishalchopra6479@gmail.com         1
# knanda658@gmail.com                1
# shambhavpatil@gmail.com            1
# ritikasingh.8oct@gmail.com         1
# nikkitewari2819@gmail.com          1
# rajatgup7415@gmail.com             1
# sangeet3132@gmail.com              1
# krpiyush0001@gmail.com             1
# shubhamsagar1310@gmail.com         1
# sauhardsrivastava@gmail.com        1
# sakshisinha21@yahoo.com            1
# Welcometoniveditacity@gmail.com    1
# rks030799@gmail.com                1
# ankitkumardbd07@gmail.com          1
# Name: Email, dtype: int64
#
# Total Email: 14

# %%
CRM30_['Assigned to'].value_counts()
# Out:
# Akshita Singh CRM              10
# Uvais Khan CRM                  7
# Princy CRM                      6
# Himanshu Negi CRM               4
# Abhishek Bhati CRM              2
# Bushra Iqbal(intern)            1
# Neha Morya (Intern)             1
# Ankita Lohani (Intern)          1
# Bharat Bhooshan Vishwakarma     1
# Kuldeep Chouhaan                1
# Deoraj Kumar                    1
# Name: Assigned to, dtype: int64

# %%
mlt.subplots(figsize=(15,9))
sns.countplot(x=CRM30_['Property Region'], hue= CRM30_['Property Region'], data = CRM30_).set_title("CRM report 31072018 Property_Region Wise")
mlt.show()

# %%
mlt.subplots(figsize=(30,9))
sns.countplot(x=CRM30_['Assigned to'], hue= CRM30_['Assigned to'], data = CRM30_).set_title("CRM report 31072018 Assigned to")
mlt.show()

# %%
mlt.subplots(figsize=(30,9))
sns.countplot(x=CRM30_['Assigned to'], hue= CRM30_['Property Region'], data = CRM30_).set_title("CRM report 29072018 Assigned to")
mlt.show()
