# %%
import networkx as nx #Graphical persentation of unshorted data
import numpy as np #calculation lib
import pandas as pd #data Shoting Lib eg:series
import matplotlib.pyplot as mlt #for plot the data 
mlt.style.use('fivethirtyeight')
import seaborn as sns #statical data vertualisation 
import plotly.offline as py #plotly is a data_virtualisation 
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls

#check_out and ls will help in the to show files and folders

from subprocess import check_output
print(check_output(["ls"]).decode("utf8"))
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# hms_db.sql
# modes_tenants_until_21072018.png
# monthly_property_Report_test.ipynb
# month_report_notebook.ipynb
# Paid_Pending.png
# persent_mode_report.ipynb
# PF009_2_may.png
# PF009.csv
# PF009_may.png
# README.md
# sheet.csv
# tbl_amenities.columns
# tbl_amenities.csv
# tbl_bed_allotment.columns
# tbl_bed_allotment.csv
# tbl_city.columns
# tbl_city.csv
# tbl_city_university.columns
# tbl_city_university.csv
# tbl_contact_us.columns
# tbl_contact_us.csv
# tbl_course.columns
# tbl_course.csv
# tbl_course_subsection.columns
# tbl_course_subsection.csv
# tbl_email_template.columns
# tbl_email_template.csv
# tbl_mobile_template.columns
# tbl_mobile_template.csv
# tbl_module.columns
# tbl_module.csv
# tbl_owner_e_kyc_b_detail.columns
# tbl_owner_e_kyc_b_detail.csv
# tbl_owner_e_kyc.columns
# tbl_owner_e_kyc.csv
# tbl_pay_rent.columns
# tbl_pay_rent.csv
# tbl_privileges.columns
# tbl_privileges.csv
# tbl_property.columns
# tbl_property.csv
# tbl_property_detail.columns
# tbl_property_detail.csv
# tbl_property_feasibility.columns
# tbl_property_feasibility.csv
# tbl_property_feasibility_setting.columns
# tbl_property_feasibility_setting.csv
# tbl_property_floor.columns
# tbl_property_floor.csv
# tbl_property_floor_room_bed.columns
# tbl_property_floor_room_bed.csv
# tbl_property_floor_room.columns
# tbl_property_floor_room.csv
# tbl_property_images.columns
# tbl_property_images.csv
# tbl_property_update_history.columns
# tbl_property_update_history.csv
# tbl_property_vr_images.columns
# tbl_property_vr_images.csv
# tbl_psat.columns
# tbl_psat.csv
# tbl_setting.columns
# tbl_setting.csv
# tbl_setting_hostel_block.columns
# tbl_setting_hostel_block.csv
# tbl_setting_hostel_type.columns
# tbl_setting_hostel_type.csv
# tbl_tenant_collect_fee.columns
# tbl_tenant_collect_fee.csv
# tbl_tenant_fee_setting.columns
# tbl_tenant_fee_setting.csv
# tbl_tenant_fee_setting_month.columns
# tbl_tenant_fee_setting_month.csv
# tbl_user_complaint.columns
# tbl_user_complaint.csv
# tbl_user_course.columns
# tbl_user_course.csv
# tbl_user_details.columns
# tbl_user_details.csv
# tbl_user_parent.columns
# tbl_user_parent.csv
# tbl_user_roles.columns
# tbl_user_roles.csv
# tbl_users.columns
# tbl_users.csv
# tbl_users_log.columns
# tbl_users_log.csv
# tbl_user_type.columns
# tbl_user_type.csv
# tbl_user_visitor.columns
# tbl_user_visitor.csv

# %%
modeR = pd.read_csv('tbl_tenant_collect_fee.csv')

# %%
modeR
# Out:
#       id    invoice_id  property_id  cluster_manager_id  manager_id  \
# 0      1    2018PM0071            1                 512           3
# 1      2    2018PM0082            7                 512          75
# 2      3    2018PM0083            7                 512          75
# 3      4    2018PM0084            7                 512          75
# 4      5    2018PM0085            7                 512          75
# 5      6    2018PM0086            7                 512          75
# 6      7    2018PM0087            7                 512          75
# 7      8    2018PM0088            7                 512          75
# 8      9    2018PM0089            7                 512          75
# 9     10   2018PM00810            7                 512          75
# 10    11   2018PM00811            7                 512          75
# 11    12   2018PM00812            7                 512          75
# 12    13   2018PM00813            7                 512          75
# 13    14   2018PM00814            7                 512          75
# 14    15   2018PM00815            7                 512          75
# 15    16   2018PM00816            7                 512          75
# 16    17   2018PM00817            7                 512          75
# 17    18   2018PM00818            7                 512          75
# 18    19   2018PM00819            7                 512          75
# 19    20   2018PM00820            7                 512          75
# 20    21   2018PF00221           33                  58           0
# 21    22   2018PF00222           33                  58           0
# 22    23   2018PF00423           16                 512           0
# 23    24   2018PF00424           16                 512           0
# 24    25   2018PF00425           16                 512           0
# 25    26   2018PF00426           16                 512           0
# 26    27   2018PM00227           72                 611        1318
# 27    28   2018PM00228           72                 611        1318
# 28    29   2018PM00229           72                 611        1318
# 29    30   2018PM00230           72                 611        1318
# ..   ...           ...          ...                 ...         ...
# 644  697  2018PF034697           61                 651           0
# 645  698  2018PF034698           61                 651           0
# 646  699  2018PF034699           61                 651           0
# 647  700  2018PF034700           61                 651           0
# 648  701  2018PF034701           61                 651           0
# 649  702  2018PF034702           61                 651           0
# 650  703  2018PF034703           61                 651           0
# 651  704  2018PM026704           50                 651           0
# 652  705  2018PM024705           54                 953        1080
# 653  706  2018PF034706           61                 651           0
# 654  707  2018PF034707           61                 651           0
# 655  708  2018PF034708           61                 651           0
# 656  709  2018PF034709           61                 651           0
# 657  710  2018PF034710           61                 651           0
# 658  711  2018PF034711           61                 651           0
# 659  712  2018PF034712           61                 651           0
# 660  713  2018PM026713           50                 651           0
# 661  714  2018PM024714           54                 953        1080
# 662  715  2018PM024715           54                 953        1080
# 663  716  2018PM024716           54                 953        1080
# 664  717  2018PM024717           54                 953        1080
# 665  718  2018PM024718           54                 953        1080
# 666  719  2018PM026719           50                 651           0
# 667  720  2018PM026720           50                 651           0
# 668  721  2018PF012721           22                 651           0
# 669  722  2018PF012722           22                 651           0
# 670  723  2018PF012723           22                 651           0
# 671  724  2018PF012724           22                 651           0
# 672  725  2018PF012725           22                 651           0
# 673  726  2018PF012726           22                 651           0
#
#      tenant_id  collect_fee  collected_amt  late_fine  due_amount  \
# 0          141     125000.0            NaN          0     96000.0
# 1          914       5500.0            NaN          0    216000.0
# 2          921       5500.0            NaN          0    240000.0
# 3           29     108000.0            NaN          0    113500.0
# 4          921     239000.0            NaN          0      1000.0
# 5          921       1000.0            NaN          0         0.0
# 6          919       5500.0            NaN          0    240000.0
# 7          919     239900.0            NaN          0       100.0
# 8          919        100.0            NaN          0         0.0
# 9         1333      54000.0            NaN          0    167500.0
# 10         913     132000.0            NaN          0    132000.0
# 11         914     108000.0            NaN          0    108000.0
# 12          30        500.0            NaN          0    245000.0
# 13         325      60000.0            NaN          0    161500.0
# 14         325        500.0            NaN          0    161000.0
# 15          21       5500.0            NaN          0    216000.0
# 16         170       5500.0            NaN          0    216000.0
# 17         170      54000.0            NaN          0    162000.0
# 18          29       5500.0            NaN          0    108000.0
# 19         917       5500.0            NaN          0    216000.0
# 20        1022       5500.0            NaN          0    204000.0
# 21         483       5500.0            NaN          0    204000.0
# 22         312      72000.0            NaN          0     89500.0
# 23        1072      36000.0            NaN          0    119500.0
# 24        1076      43200.0            NaN          0    112300.0
# 25        1077      75000.0            NaN          0     80500.0
# 26         974       5500.0            NaN          0    240000.0
# 27        1091       5500.0            NaN          0    168000.0
# 28        1149       5500.0            NaN          0    132000.0
# 29        1260       5500.0            NaN          0    132000.0
# ..         ...          ...            ...        ...         ...
# 644       1502      10000.0            NaN          0    -30001.0
# 645       1502       6000.0            NaN          0    -36001.0
# 646       1503      41500.0            NaN          0    -41500.0
# 647       1506      41000.0            NaN          0    -35000.0
# 648       2032       5500.0            NaN          0         0.0
# 649       2034        500.0            NaN          0     29000.0
# 650       2034      43500.0            NaN          0    -14500.0
# 651       2037      32500.0            NaN          0     99500.0
# 652       2038      26500.0            NaN          0     26000.0
# 653       2039       5500.0            NaN          0         0.0
# 654       2039       5500.0            NaN          0         0.0
# 655       2040      38000.0            NaN          0    -30000.0
# 656       1766      32500.0            NaN          0    -32500.0
# 657       1762      40000.0            NaN          0    -40000.0
# 658       1765      35000.0            NaN          0    -29500.0
# 659       1764      40000.0            NaN          0    -40000.0
# 660       1593       5500.0            NaN          0    -36500.0
# 661       2041      14000.0            NaN          0     59500.0
# 662       1304      18000.0            NaN          0     45000.0
# 663       2042      14500.0            NaN          0     59000.0
# 664       2043      26000.0            NaN          0     47500.0
# 665       2045      10000.0            NaN          0     42500.0
# 666       2037       5500.0            NaN          0     94000.0
# 667       1674      35500.0            NaN          0    -30000.0
# 668       1805      25000.0            NaN          0     79500.0
# 669       1944      33500.0            NaN          0     98500.0
# 670       2047       9000.0            NaN          0    123000.0
# 671       2048       5500.0            NaN          0     -5500.0
# 672       2048      26250.0            NaN          0    -31750.0
# 673       2049       5000.0            NaN          0    127000.0
#
#         ...          neft_rtgs_utr  \
# 0       ...                    NaN
# 1       ...                    NaN
# 2       ...                    NaN
# 3       ...                    NaN
# 4       ...                   RTGS
# 5       ...                    NaN
# 6       ...                    NaN
# 7       ...                    NaN
# 8       ...                    NaN
# 9       ...       UTBIN18164631159
# 10      ...                    NaN
# 11      ...           000046285958
# 12      ...                    NaN
# 13      ...                    NaN
# 14      ...                    NaN
# 15      ...                    NaN
# 16      ...                    NaN
# 17      ...                    NaN
# 18      ...                    NaN
# 19      ...                    NaN
# 20      ...                    NaN
# 21      ...                    NaN
# 22      ...                    NaN
# 23      ...              211070869
# 24      ...             PF004/303A
# 25      ...                    NaN
# 26      ...                    NaN
# 27      ...                    NaN
# 28      ...                    NaN
# 29      ...                    NaN
# ..      ...                    ...
# 644     ...                    NaN
# 645     ...                    NaN
# 646     ...                    NaN
# 647     ...                    NaN
# 648     ...                    NaN
# 649     ...                    NaN
# 650     ...                    NaN
# 651     ...                    NaN
# 652     ...                    NaN
# 653     ...                    NaN
# 654     ...                    NaN
# 655     ...                    NaN
# 656     ...                    NaN
# 657     ...                    NaN
# 658     ...                    NaN
# 659     ...                    NaN
# 660     ...                    NaN
# 661     ...                    NaN
# 662     ...                    NaN
# 663     ...                    NaN
# 664     ...                    NaN
# 665     ...                    NaN
# 666     ...                    NaN
# 667     ...                    NaN
# 668     ...                    NaN
# 669     ...                    NaN
# 670     ...                    NaN
# 671     ...                    NaN
# 672     ...                    NaN
# 673     ...                    NaN
#
#                                                remark month_id paid_by  \
# 0                                         Amount Paid      NaN     512
# 1                                         Amount Paid      NaN    1314
# 2                                         Amount Paid      NaN    1314
# 3                                         Amount Paid      NaN    1314
# 4                                         Amount Paid      NaN    1314
# 5                                         Amount Paid      NaN    1314
# 6                                         Amount Paid      NaN    1314
# 7                                         Amount Paid      NaN    1314
# 8                                         Amount Paid      NaN    1314
# 9                                         Amount Paid      NaN    1314
# 10                                        Amount Paid      NaN    1314
# 11                                        Amount Paid      NaN    1314
# 12                                        Amount Paid      NaN    1314
# 13                                        Amount Paid      NaN    1314
# 14                                        Amount Paid      NaN    1314
# 15                                        Amount Paid      NaN    1314
# 16                                        Amount Paid      NaN    1314
# 17                                        Amount Paid      NaN    1314
# 18                                        Amount Paid      NaN    1314
# 19                                        Amount Paid      NaN    1314
# 20                                        Amount Paid      NaN    1314
# 21                                        Amount Paid      NaN    1314
# 22                                        Amount Paid      NaN    1314
# 23                                        Amount Paid      NaN    1314
# 24                                        Amount Paid      NaN    1314
# 25                                        Amount Paid      NaN    1314
# 26                                        Amount Paid      NaN    1314
# 27                                        Amount Paid      NaN    1314
# 28                                        Amount Paid      NaN    1314
# 29                                        Amount Paid      NaN    1314
# ..                                                ...      ...     ...
# 644                                       Amount Paid      NaN     651
# 645                                       Amount Paid      NaN     651
# 646                  Amount Paid\r\nRENT+SECURITY\r\n      NaN     651
# 647                      Amount Paid\r\nRENT+SECURITY      NaN     651
# 648                                       Amount Paid      NaN     651
# 649                                       Amount Paid      NaN     651
# 650                      Amount Paid\r\nRENT+SECURITY      NaN     651
# 651  Amount Paid\r\nRENT - 12500 \r\nSECURITY - 25000      NaN     642
# 652                               Amount Paid on cash      NaN    1080
# 653                                       Amount Paid      NaN     651
# 654                                       Amount Paid      NaN     651
# 655       Amount Paid\r\nRENT- 7500\r\nDEPOSIT- 30000      NaN     651
# 656  Amount Paid\r\nRENT- 7500\r\nSECURITY- 30000\r\n      NaN     651
# 657      Amount Paid\r\nRENT- 10000\r\nDEPOSIT- 30000      NaN     651
# 658       Amount Paid\r\nRENT- 5000\r\nDEPOSIT- 30000      NaN     651
# 659     Amount Paid\r\nRENT- 10000\r\nSECURITY- 30000      NaN     651
# 660                                       Amount Paid      NaN     651
# 661                                       Amount Paid      NaN    1080
# 662                               Amount Paid ON NEFT      NaN    1080
# 663                               Amount Paid ON NEFT      NaN    1080
# 664                               Amount Paid ON NEFT      NaN    1080
# 665                               Amount Paid on cash      NaN    1080
# 666                                       Amount Paid      NaN     642
# 667    Amount Paid\r\nRENT -13500\r\nSECURITY - 27000      NaN     642
# 668               july rent 5000+security money 20000      NaN     651
# 669       security 22000+11000 rent july+500 move in       NaN     651
# 670                                    july rent paid      NaN     651
# 671                   booking amount5000+500 move in       NaN     651
# 672   25000 security money+1250 july rent on pro data      NaN     651
# 673                  Amount Paid july half month rent      NaN     651
#
#     approved_by  payment_id   status create_date  update_by  update_date
# 0             0         NaN        0  2018-06-28          0          NaN
# 1             0         NaN     paid  2018-05-10          0          NaN
# 2             0         NaN     paid  2018-04-21          0          NaN
# 3             0         NaN     paid  2018-05-25          0          NaN
# 4             0         NaN  pending  2018-05-08          0          NaN
# 5             0         NaN     paid  2018-05-06          0          NaN
# 6             0         NaN     paid  2018-04-21          0          NaN
# 7             0         NaN     paid  2018-05-10          0          NaN
# 8             0         NaN     paid  2018-05-10          0          NaN
# 9             0         NaN     paid  2018-06-13          0          NaN
# 10            0         NaN  pending  2018-06-28          0          NaN
# 11            0         NaN     paid  2018-05-29          0          NaN
# 12            0         NaN     paid  2018-04-27          0          NaN
# 13            0         NaN     paid  2018-06-21          0          NaN
# 14            0         NaN     paid  2018-04-27          0          NaN
# 15            0         NaN     paid  2018-04-19          0          NaN
# 16            0         NaN     paid  2018-04-17          0          NaN
# 17            0         NaN     paid  2018-05-25          0          NaN
# 18            0         NaN     paid  2018-04-13          0          NaN
# 19            0         NaN     paid  2018-04-19          0          NaN
# 20            0         NaN     paid  2018-05-07          0          NaN
# 21            0         NaN        0  2018-05-07          0          NaN
# 22            0         NaN     paid  2018-05-10          0          NaN
# 23            0         NaN  pending  2018-06-12          0          NaN
# 24            0         NaN     paid  2018-06-25          0          NaN
# 25            0         NaN        0  2018-06-25          0          NaN
# 26            0         NaN     paid  2018-06-20          0          NaN
# 27            0         NaN     paid  2018-06-23          0          NaN
# 28            0         NaN  pending  2018-06-29          0          NaN
# 29            0         NaN     paid  2018-06-25          0          NaN
# ..          ...         ...      ...         ...        ...          ...
# 644           0         NaN  pending  2018-07-22          0          NaN
# 645           0         NaN  pending  2018-07-22          0          NaN
# 646           0         NaN  pending  2018-07-22          0          NaN
# 647           0         NaN        0  2018-07-22          0          NaN
# 648           0         NaN  pending  2018-07-22          0          NaN
# 649           0         NaN  pending  2018-07-22          0          NaN
# 650           0         NaN  pending  2018-07-22          0          NaN
# 651           0         NaN  pending  2018-07-22          0          NaN
# 652           0         NaN  pending  2018-07-22          0          NaN
# 653           0         NaN  pending  2018-07-22          0          NaN
# 654           0         NaN  pending  2018-07-22          0          NaN
# 655           0         NaN  pending  2018-07-22          0          NaN
# 656           0         NaN  pending  2018-07-22          0          NaN
# 657           0         NaN  pending  2018-07-22          0          NaN
# 658           0         NaN  pending  2018-07-22          0          NaN
# 659           0         NaN  pending  2018-07-22          0          NaN
# 660           0         NaN        0  2018-07-22          0          NaN
# 661           0         NaN  pending  2018-07-22          0          NaN
# 662           0         NaN  pending  2018-07-22          0          NaN
# 663           0         NaN  pending  2018-07-22          0          NaN
# 664           0         NaN  pending  2018-07-22          0          NaN
# 665           0         NaN  pending  2018-07-22          0          NaN
# 666           0         NaN  pending  2018-07-22          0          NaN
# 667           0         NaN  pending  2018-07-23          0          NaN
# 668           0         NaN  pending  2018-07-22          0          NaN
# 669           0         NaN  pending  2018-07-19          0          NaN
# 670           0         NaN  pending  2018-07-10          0          NaN
# 671           0         NaN  pending  2018-07-17          0          NaN
# 672           0         NaN  pending  2018-07-22          0          NaN
# 673           0         NaN  pending  2018-07-21          0          NaN
#
# [674 rows x 26 columns]

# %%
modeR['payment_mode']
# Out:
# 0        cash
# 1        cash
# 2        cash
# 3        cash
# 4      online
# 5        cash
# 6        cash
# 7        cash
# 8        cash
# 9      online
# 10       cash
# 11     online
# 12       cash
# 13       cash
# 14       cash
# 15       cash
# 16       cash
# 17       cash
# 18       cash
# 19       cash
# 20       cash
# 21       cash
# 22     cheque
# 23     online
# 24     online
# 25       cash
# 26      paytm
# 27      paytm
# 28       cash
# 29      paytm
#         ...
# 644    online
# 645    online
# 646      cash
# 647      cash
# 648      cash
# 649      cash
# 650    cheque
# 651      cash
# 652      cash
# 653      cash
# 654      cash
# 655      cash
# 656      cash
# 657      cash
# 658      cash
# 659      cash
# 660     paytm
# 661      cash
# 662      cash
# 663      cash
# 664      cash
# 665      cash
# 666      cash
# 667    online
# 668     paytm
# 669      cash
# 670      cash
# 671    online
# 672      cash
# 673    online
# Name: payment_mode, Length: 674, dtype: object

# %%
mlt.subplots(figsize=(20,18))
sns.countplot(x=modeR['payment_mode'],hue=modeR['payment_mode'], data=modeR).set_title("Graph of modes using by tenants until 21/07/2018")
#mlt.savefig('modes_tenants_until_21072018.png')
mlt.show()

# %%
b = modeR[modeR.status > 0]
b
# Out:
#       id    invoice_id  property_id  cluster_manager_id  manager_id  \
# 0      1    2018PM0071            1                 512           3
# 1      2    2018PM0082            7                 512          75
# 2      3    2018PM0083            7                 512          75
# 3      4    2018PM0084            7                 512          75
# 4      5    2018PM0085            7                 512          75
# 5      6    2018PM0086            7                 512          75
# 6      7    2018PM0087            7                 512          75
# 7      8    2018PM0088            7                 512          75
# 8      9    2018PM0089            7                 512          75
# 9     10   2018PM00810            7                 512          75
# 10    11   2018PM00811            7                 512          75
# 11    12   2018PM00812            7                 512          75
# 12    13   2018PM00813            7                 512          75
# 13    14   2018PM00814            7                 512          75
# 14    15   2018PM00815            7                 512          75
# 15    16   2018PM00816            7                 512          75
# 16    17   2018PM00817            7                 512          75
# 17    18   2018PM00818            7                 512          75
# 18    19   2018PM00819            7                 512          75
# 19    20   2018PM00820            7                 512          75
# 20    21   2018PF00221           33                  58           0
# 21    22   2018PF00222           33                  58           0
# 22    23   2018PF00423           16                 512           0
# 23    24   2018PF00424           16                 512           0
# 24    25   2018PF00425           16                 512           0
# 25    26   2018PF00426           16                 512           0
# 26    27   2018PM00227           72                 611        1318
# 27    28   2018PM00228           72                 611        1318
# 28    29   2018PM00229           72                 611        1318
# 29    30   2018PM00230           72                 611        1318
# ..   ...           ...          ...                 ...         ...
# 644  697  2018PF034697           61                 651           0
# 645  698  2018PF034698           61                 651           0
# 646  699  2018PF034699           61                 651           0
# 647  700  2018PF034700           61                 651           0
# 648  701  2018PF034701           61                 651           0
# 649  702  2018PF034702           61                 651           0
# 650  703  2018PF034703           61                 651           0
# 651  704  2018PM026704           50                 651           0
# 652  705  2018PM024705           54                 953        1080
# 653  706  2018PF034706           61                 651           0
# 654  707  2018PF034707           61                 651           0
# 655  708  2018PF034708           61                 651           0
# 656  709  2018PF034709           61                 651           0
# 657  710  2018PF034710           61                 651           0
# 658  711  2018PF034711           61                 651           0
# 659  712  2018PF034712           61                 651           0
# 660  713  2018PM026713           50                 651           0
# 661  714  2018PM024714           54                 953        1080
# 662  715  2018PM024715           54                 953        1080
# 663  716  2018PM024716           54                 953        1080
# 664  717  2018PM024717           54                 953        1080
# 665  718  2018PM024718           54                 953        1080
# 666  719  2018PM026719           50                 651           0
# 667  720  2018PM026720           50                 651           0
# 668  721  2018PF012721           22                 651           0
# 669  722  2018PF012722           22                 651           0
# 670  723  2018PF012723           22                 651           0
# 671  724  2018PF012724           22                 651           0
# 672  725  2018PF012725           22                 651           0
# 673  726  2018PF012726           22                 651           0
#
#      tenant_id  collect_fee  collected_amt  late_fine  due_amount  \
# 0          141     125000.0            NaN          0     96000.0
# 1          914       5500.0            NaN          0    216000.0
# 2          921       5500.0            NaN          0    240000.0
# 3           29     108000.0            NaN          0    113500.0
# 4          921     239000.0            NaN          0      1000.0
# 5          921       1000.0            NaN          0         0.0
# 6          919       5500.0            NaN          0    240000.0
# 7          919     239900.0            NaN          0       100.0
# 8          919        100.0            NaN          0         0.0
# 9         1333      54000.0            NaN          0    167500.0
# 10         913     132000.0            NaN          0    132000.0
# 11         914     108000.0            NaN          0    108000.0
# 12          30        500.0            NaN          0    245000.0
# 13         325      60000.0            NaN          0    161500.0
# 14         325        500.0            NaN          0    161000.0
# 15          21       5500.0            NaN          0    216000.0
# 16         170       5500.0            NaN          0    216000.0
# 17         170      54000.0            NaN          0    162000.0
# 18          29       5500.0            NaN          0    108000.0
# 19         917       5500.0            NaN          0    216000.0
# 20        1022       5500.0            NaN          0    204000.0
# 21         483       5500.0            NaN          0    204000.0
# 22         312      72000.0            NaN          0     89500.0
# 23        1072      36000.0            NaN          0    119500.0
# 24        1076      43200.0            NaN          0    112300.0
# 25        1077      75000.0            NaN          0     80500.0
# 26         974       5500.0            NaN          0    240000.0
# 27        1091       5500.0            NaN          0    168000.0
# 28        1149       5500.0            NaN          0    132000.0
# 29        1260       5500.0            NaN          0    132000.0
# ..         ...          ...            ...        ...         ...
# 644       1502      10000.0            NaN          0    -30001.0
# 645       1502       6000.0            NaN          0    -36001.0
# 646       1503      41500.0            NaN          0    -41500.0
# 647       1506      41000.0            NaN          0    -35000.0
# 648       2032       5500.0            NaN          0         0.0
# 649       2034        500.0            NaN          0     29000.0
# 650       2034      43500.0            NaN          0    -14500.0
# 651       2037      32500.0            NaN          0     99500.0
# 652       2038      26500.0            NaN          0     26000.0
# 653       2039       5500.0            NaN          0         0.0
# 654       2039       5500.0            NaN          0         0.0
# 655       2040      38000.0            NaN          0    -30000.0
# 656       1766      32500.0            NaN          0    -32500.0
# 657       1762      40000.0            NaN          0    -40000.0
# 658       1765      35000.0            NaN          0    -29500.0
# 659       1764      40000.0            NaN          0    -40000.0
# 660       1593       5500.0            NaN          0    -36500.0
# 661       2041      14000.0            NaN          0     59500.0
# 662       1304      18000.0            NaN          0     45000.0
# 663       2042      14500.0            NaN          0     59000.0
# 664       2043      26000.0            NaN          0     47500.0
# 665       2045      10000.0            NaN          0     42500.0
# 666       2037       5500.0            NaN          0     94000.0
# 667       1674      35500.0            NaN          0    -30000.0
# 668       1805      25000.0            NaN          0     79500.0
# 669       1944      33500.0            NaN          0     98500.0
# 670       2047       9000.0            NaN          0    123000.0
# 671       2048       5500.0            NaN          0     -5500.0
# 672       2048      26250.0            NaN          0    -31750.0
# 673       2049       5000.0            NaN          0    127000.0
#
#         ...          neft_rtgs_utr  \
# 0       ...                    NaN
# 1       ...                    NaN
# 2       ...                    NaN
# 3       ...                    NaN
# 4       ...                   RTGS
# 5       ...                    NaN
# 6       ...                    NaN
# 7       ...                    NaN
# 8       ...                    NaN
# 9       ...       UTBIN18164631159
# 10      ...                    NaN
# 11      ...           000046285958
# 12      ...                    NaN
# 13      ...                    NaN
# 14      ...                    NaN
# 15      ...                    NaN
# 16      ...                    NaN
# 17      ...                    NaN
# 18      ...                    NaN
# 19      ...                    NaN
# 20      ...                    NaN
# 21      ...                    NaN
# 22      ...                    NaN
# 23      ...              211070869
# 24      ...             PF004/303A
# 25      ...                    NaN
# 26      ...                    NaN
# 27      ...                    NaN
# 28      ...                    NaN
# 29      ...                    NaN
# ..      ...                    ...
# 644     ...                    NaN
# 645     ...                    NaN
# 646     ...                    NaN
# 647     ...                    NaN
# 648     ...                    NaN
# 649     ...                    NaN
# 650     ...                    NaN
# 651     ...                    NaN
# 652     ...                    NaN
# 653     ...                    NaN
# 654     ...                    NaN
# 655     ...                    NaN
# 656     ...                    NaN
# 657     ...                    NaN
# 658     ...                    NaN
# 659     ...                    NaN
# 660     ...                    NaN
# 661     ...                    NaN
# 662     ...                    NaN
# 663     ...                    NaN
# 664     ...                    NaN
# 665     ...                    NaN
# 666     ...                    NaN
# 667     ...                    NaN
# 668     ...                    NaN
# 669     ...                    NaN
# 670     ...                    NaN
# 671     ...                    NaN
# 672     ...                    NaN
# 673     ...                    NaN
#
#                                                remark month_id paid_by  \
# 0                                         Amount Paid      NaN     512
# 1                                         Amount Paid      NaN    1314
# 2                                         Amount Paid      NaN    1314
# 3                                         Amount Paid      NaN    1314
# 4                                         Amount Paid      NaN    1314
# 5                                         Amount Paid      NaN    1314
# 6                                         Amount Paid      NaN    1314
# 7                                         Amount Paid      NaN    1314
# 8                                         Amount Paid      NaN    1314
# 9                                         Amount Paid      NaN    1314
# 10                                        Amount Paid      NaN    1314
# 11                                        Amount Paid      NaN    1314
# 12                                        Amount Paid      NaN    1314
# 13                                        Amount Paid      NaN    1314
# 14                                        Amount Paid      NaN    1314
# 15                                        Amount Paid      NaN    1314
# 16                                        Amount Paid      NaN    1314
# 17                                        Amount Paid      NaN    1314
# 18                                        Amount Paid      NaN    1314
# 19                                        Amount Paid      NaN    1314
# 20                                        Amount Paid      NaN    1314
# 21                                        Amount Paid      NaN    1314
# 22                                        Amount Paid      NaN    1314
# 23                                        Amount Paid      NaN    1314
# 24                                        Amount Paid      NaN    1314
# 25                                        Amount Paid      NaN    1314
# 26                                        Amount Paid      NaN    1314
# 27                                        Amount Paid      NaN    1314
# 28                                        Amount Paid      NaN    1314
# 29                                        Amount Paid      NaN    1314
# ..                                                ...      ...     ...
# 644                                       Amount Paid      NaN     651
# 645                                       Amount Paid      NaN     651
# 646                  Amount Paid\r\nRENT+SECURITY\r\n      NaN     651
# 647                      Amount Paid\r\nRENT+SECURITY      NaN     651
# 648                                       Amount Paid      NaN     651
# 649                                       Amount Paid      NaN     651
# 650                      Amount Paid\r\nRENT+SECURITY      NaN     651
# 651  Amount Paid\r\nRENT - 12500 \r\nSECURITY - 25000      NaN     642
# 652                               Amount Paid on cash      NaN    1080
# 653                                       Amount Paid      NaN     651
# 654                                       Amount Paid      NaN     651
# 655       Amount Paid\r\nRENT- 7500\r\nDEPOSIT- 30000      NaN     651
# 656  Amount Paid\r\nRENT- 7500\r\nSECURITY- 30000\r\n      NaN     651
# 657      Amount Paid\r\nRENT- 10000\r\nDEPOSIT- 30000      NaN     651
# 658       Amount Paid\r\nRENT- 5000\r\nDEPOSIT- 30000      NaN     651
# 659     Amount Paid\r\nRENT- 10000\r\nSECURITY- 30000      NaN     651
# 660                                       Amount Paid      NaN     651
# 661                                       Amount Paid      NaN    1080
# 662                               Amount Paid ON NEFT      NaN    1080
# 663                               Amount Paid ON NEFT      NaN    1080
# 664                               Amount Paid ON NEFT      NaN    1080
# 665                               Amount Paid on cash      NaN    1080
# 666                                       Amount Paid      NaN     642
# 667    Amount Paid\r\nRENT -13500\r\nSECURITY - 27000      NaN     642
# 668               july rent 5000+security money 20000      NaN     651
# 669       security 22000+11000 rent july+500 move in       NaN     651
# 670                                    july rent paid      NaN     651
# 671                   booking amount5000+500 move in       NaN     651
# 672   25000 security money+1250 july rent on pro data      NaN     651
# 673                  Amount Paid july half month rent      NaN     651
#
#     approved_by  payment_id   status create_date  update_by  update_date
# 0             0         NaN        0  2018-06-28          0          NaN
# 1             0         NaN     paid  2018-05-10          0          NaN
# 2             0         NaN     paid  2018-04-21          0          NaN
# 3             0         NaN     paid  2018-05-25          0          NaN
# 4             0         NaN  pending  2018-05-08          0          NaN
# 5             0         NaN     paid  2018-05-06          0          NaN
# 6             0         NaN     paid  2018-04-21          0          NaN
# 7             0         NaN     paid  2018-05-10          0          NaN
# 8             0         NaN     paid  2018-05-10          0          NaN
# 9             0         NaN     paid  2018-06-13          0          NaN
# 10            0         NaN  pending  2018-06-28          0          NaN
# 11            0         NaN     paid  2018-05-29          0          NaN
# 12            0         NaN     paid  2018-04-27          0          NaN
# 13            0         NaN     paid  2018-06-21          0          NaN
# 14            0         NaN     paid  2018-04-27          0          NaN
# 15            0         NaN     paid  2018-04-19          0          NaN
# 16            0         NaN     paid  2018-04-17          0          NaN
# 17            0         NaN     paid  2018-05-25          0          NaN
# 18            0         NaN     paid  2018-04-13          0          NaN
# 19            0         NaN     paid  2018-04-19          0          NaN
# 20            0         NaN     paid  2018-05-07          0          NaN
# 21            0         NaN        0  2018-05-07          0          NaN
# 22            0         NaN     paid  2018-05-10          0          NaN
# 23            0         NaN  pending  2018-06-12          0          NaN
# 24            0         NaN     paid  2018-06-25          0          NaN
# 25            0         NaN        0  2018-06-25          0          NaN
# 26            0         NaN     paid  2018-06-20          0          NaN
# 27            0         NaN     paid  2018-06-23          0          NaN
# 28            0         NaN  pending  2018-06-29          0          NaN
# 29            0         NaN     paid  2018-06-25          0          NaN
# ..          ...         ...      ...         ...        ...          ...
# 644           0         NaN  pending  2018-07-22          0          NaN
# 645           0         NaN  pending  2018-07-22          0          NaN
# 646           0         NaN  pending  2018-07-22          0          NaN
# 647           0         NaN        0  2018-07-22          0          NaN
# 648           0         NaN  pending  2018-07-22          0          NaN
# 649           0         NaN  pending  2018-07-22          0          NaN
# 650           0         NaN  pending  2018-07-22          0          NaN
# 651           0         NaN  pending  2018-07-22          0          NaN
# 652           0         NaN  pending  2018-07-22          0          NaN
# 653           0         NaN  pending  2018-07-22          0          NaN
# 654           0         NaN  pending  2018-07-22          0          NaN
# 655           0         NaN  pending  2018-07-22          0          NaN
# 656           0         NaN  pending  2018-07-22          0          NaN
# 657           0         NaN  pending  2018-07-22          0          NaN
# 658           0         NaN  pending  2018-07-22          0          NaN
# 659           0         NaN  pending  2018-07-22          0          NaN
# 660           0         NaN        0  2018-07-22          0          NaN
# 661           0         NaN  pending  2018-07-22          0          NaN
# 662           0         NaN  pending  2018-07-22          0          NaN
# 663           0         NaN  pending  2018-07-22          0          NaN
# 664           0         NaN  pending  2018-07-22          0          NaN
# 665           0         NaN  pending  2018-07-22          0          NaN
# 666           0         NaN  pending  2018-07-22          0          NaN
# 667           0         NaN  pending  2018-07-23          0          NaN
# 668           0         NaN  pending  2018-07-22          0          NaN
# 669           0         NaN  pending  2018-07-19          0          NaN
# 670           0         NaN  pending  2018-07-10          0          NaN
# 671           0         NaN  pending  2018-07-17          0          NaN
# 672           0         NaN  pending  2018-07-22          0          NaN
# 673           0         NaN  pending  2018-07-21          0          NaN
#
# [674 rows x 26 columns]

# %%
mlt.subplots(figsize=(20,18))
sns.countplot(x=b['status'],hue=b['status'], data=b).set_title("Graph for Paid/Pending until 21/07/2018")
#mlt.savefig('Paid_Pending.png')
mlt.show()

# %%
d = b.loc[:,['tenant_id','collect_fee','due_amount']]
d
# Out:
#      tenant_id  collect_fee  due_amount
# 0          141     125000.0     96000.0
# 1          914       5500.0    216000.0
# 2          921       5500.0    240000.0
# 3           29     108000.0    113500.0
# 4          921     239000.0      1000.0
# 5          921       1000.0         0.0
# 6          919       5500.0    240000.0
# 7          919     239900.0       100.0
# 8          919        100.0         0.0
# 9         1333      54000.0    167500.0
# 10         913     132000.0    132000.0
# 11         914     108000.0    108000.0
# 12          30        500.0    245000.0
# 13         325      60000.0    161500.0
# 14         325        500.0    161000.0
# 15          21       5500.0    216000.0
# 16         170       5500.0    216000.0
# 17         170      54000.0    162000.0
# 18          29       5500.0    108000.0
# 19         917       5500.0    216000.0
# 20        1022       5500.0    204000.0
# 21         483       5500.0    204000.0
# 22         312      72000.0     89500.0
# 23        1072      36000.0    119500.0
# 24        1076      43200.0    112300.0
# 25        1077      75000.0     80500.0
# 26         974       5500.0    240000.0
# 27        1091       5500.0    168000.0
# 28        1149       5500.0    132000.0
# 29        1260       5500.0    132000.0
# ..         ...          ...         ...
# 644       1502      10000.0    -30001.0
# 645       1502       6000.0    -36001.0
# 646       1503      41500.0    -41500.0
# 647       1506      41000.0    -35000.0
# 648       2032       5500.0         0.0
# 649       2034        500.0     29000.0
# 650       2034      43500.0    -14500.0
# 651       2037      32500.0     99500.0
# 652       2038      26500.0     26000.0
# 653       2039       5500.0         0.0
# 654       2039       5500.0         0.0
# 655       2040      38000.0    -30000.0
# 656       1766      32500.0    -32500.0
# 657       1762      40000.0    -40000.0
# 658       1765      35000.0    -29500.0
# 659       1764      40000.0    -40000.0
# 660       1593       5500.0    -36500.0
# 661       2041      14000.0     59500.0
# 662       1304      18000.0     45000.0
# 663       2042      14500.0     59000.0
# 664       2043      26000.0     47500.0
# 665       2045      10000.0     42500.0
# 666       2037       5500.0     94000.0
# 667       1674      35500.0    -30000.0
# 668       1805      25000.0     79500.0
# 669       1944      33500.0     98500.0
# 670       2047       9000.0    123000.0
# 671       2048       5500.0     -5500.0
# 672       2048      26250.0    -31750.0
# 673       2049       5000.0    127000.0
#
# [674 rows x 3 columns]

# %%
mlt.subplots(figsize=(200,18))
sns.lineplot(data=d.collect_fee, color="g" )
ax2 = mlt.twinx()
sns.lineplot(data=d.due_amount, color="b", ax=ax2,)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-286b9bc1e527> in <module>()
#       2 sns.lineplot(data=d.collect_fee, color="g" )
#       3 ax2 = mlt.twinx()
# ----> 4 sns.lineplot(data=d.due_amount, color="b", ax=ax2, hue=due_amount)
#
# NameError: name 'due_amount' is not defined

# %%
d['due_amount'].groupby(d['collect_fee'].d.month).sum().plot.bar()

# %%
mlt.subplots(figsize=(20,18))
sns.barplot(x=d['tenant_id'], y=d['collect_fee'], hue=d['collect_fee'], data=d).set_title("Graph for Paid/Pending until 21/07/2018")
#mlt.savefig('Paid_Pending.png')
mlt.show()
