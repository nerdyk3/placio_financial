# %%
import networkx as nx #Graphical persentation of unshorted data
import numpy as np #calculation lib
import pandas as pd #data Shoting Lib eg:series
import matplotlib.pyplot as mlt #for plot the data 
mlt.style.use('fivethirtyeight')
import seaborn as sns #statical data vertualisation 
import plotly.offline as py #plotly is a data_virtualisation 
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls

#check_out and ls will help in the to show files and folders

from subprocess import check_output
print(check_output(["ls"]).decode("utf8"))
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# 01_Aug_HMS_F.ipynb
# 26_HMS_F.ipynb
# 27_HMS_F.ipynb
# 28_HMS_F.ipynb
# 29_HMS_F.ipynb
# 30_HMS_F.ipynb
# 31_HMS_F.ipynb
# col
# collect_and_due_amount_20180701_to_20180723.png
# cratio_25_7.csv
# cratio_25_7.ipynb
# CRM01_Aug.ipynb
# CRM02_Aug.ipynb
# CRM27_.ipynb
# CRM28_.ipynb
# CRM29_.ipynb
# CRM30_.ipynb
# CRM31_.ipynb
# csv
# due_and_collect_amount Graph.png
# FeeReport-2018-07-25 06_05_42.csv
# hms_db.sql
# kk
# modes_tenants_until_21072018.png
# month_date_range.ipynb
# monthly_property_Report_test.ipynb
# month_report_notebook.ipynb
# Paid_Pending.png
# persent_mode_report.ipynb
# PF009_2_may.png
# PF009_may.png
# README.md
# report _25_07_2018.ipynb
# status_20180701_to_20180723.png
# table.html
# test.csv
# Untitled.ipynb

# %%
HMS30_ = pd.read_csv('csv/31_july.csv')
HMS30_
# Out:
#             Property Name     Invoice ID             TXN ID  \
# 0                       -              -                  -
# 1   Placio Imperial Homez  2018PF0121019  20180731 15390900
# 2       Placio Pride Stay  2018PM0251011                NaN
# 3       Placio Pride Stay  2018PM0251010                NaN
# 4       Placio Pride Stay  2018PM0251009         IRH0353088
# 5       Placio Pride Stay  2018PM0251008               4964
# 6       Placio Pride Stay  2018PM0251007       820818869584
# 7       Placio Pride Stay  2018PM0251006       820322025754
# 8         Placio RG Niwas   2018PF009993                NaN
# 9    Placio Elite Homes 2   2018PF003992             749346
# 10   Placio Elite Homes 2   2018PF003991             749345
# 11   Placio Elite Homes 2   2018PF003990             749344
# 12      Placio Ashoka Inn   2018PM024981                NaN
# 13      Placio Ashoka Inn   2018PM024980         1501779535
#
#          Collected Amount Tenant Code           Tenant Name    Mode  \
# 0   TOTAL AMOUNT : 354100           -                     -       -
# 1                    5500    18192341        ritika jaiswal   paytm
# 2                   21500    18192160      VISHWAJEET KUMAR    cash
# 3                   10200   181901457         VISHESH SINGH    cash
# 4                   25000    18191519           AUSAF MOMIN  online
# 5                   18500    18191521          SRIJAN DIXIT  cheque
# 6                    6900   181901325          AARYAV ANAND  online
# 7                   17500   181901346        ANUJ PRAJAPATI  online
# 8                   13000    18192337            SAIMA BHAT    cash
# 9                   64000    18192290  Rajasmita Chatterjee  cheque
# 10                  64000    18192290  Rajasmita Chatterjee  cheque
# 11                  64000    18192290  Rajasmita Chatterjee  cheque
# 12                  22000    18192317          DRAVIN VERMA    cash
# 13                  22000    18192316        R C SAI CHARAN  online
#
#            Term        Date   Status
# 0             -           -        -
# 1       monthly  2018-07-31  pending
# 2       monthly  2018-07-31  pending
# 3       monthly  2018-07-31  pending
# 4       monthly  2018-07-31  pending
# 5       monthly  2018-07-31  pending
# 6       monthly  2018-07-31  pending
# 7       monthly  2018-07-31  pending
# 8       monthly  2018-07-31  pending
# 9   half-yearly  2018-07-31  pending
# 10  half-yearly  2018-07-31  pending
# 11  half-yearly  2018-07-31  pending
# 12      monthly  2018-07-31  pending
# 13      monthly  2018-07-31     paid

# %%
D30_ = HMS30_.sort_values(by='Collected Amount' , ascending= False)
D30_
# Out:
#             Property Name     Invoice ID             TXN ID  \
# 0                       -              -                  -
# 6       Placio Pride Stay  2018PM0251007       820818869584
# 9    Placio Elite Homes 2   2018PF003992             749346
# 10   Placio Elite Homes 2   2018PF003991             749345
# 11   Placio Elite Homes 2   2018PF003990             749344
# 1   Placio Imperial Homez  2018PF0121019  20180731 15390900
# 4       Placio Pride Stay  2018PM0251009         IRH0353088
# 12      Placio Ashoka Inn   2018PM024981                NaN
# 13      Placio Ashoka Inn   2018PM024980         1501779535
# 2       Placio Pride Stay  2018PM0251011                NaN
# 5       Placio Pride Stay  2018PM0251008               4964
# 7       Placio Pride Stay  2018PM0251006       820322025754
# 8         Placio RG Niwas   2018PF009993                NaN
# 3       Placio Pride Stay  2018PM0251010                NaN
#
#          Collected Amount Tenant Code           Tenant Name    Mode  \
# 0   TOTAL AMOUNT : 354100           -                     -       -
# 6                    6900   181901325          AARYAV ANAND  online
# 9                   64000    18192290  Rajasmita Chatterjee  cheque
# 10                  64000    18192290  Rajasmita Chatterjee  cheque
# 11                  64000    18192290  Rajasmita Chatterjee  cheque
# 1                    5500    18192341        ritika jaiswal   paytm
# 4                   25000    18191519           AUSAF MOMIN  online
# 12                  22000    18192317          DRAVIN VERMA    cash
# 13                  22000    18192316        R C SAI CHARAN  online
# 2                   21500    18192160      VISHWAJEET KUMAR    cash
# 5                   18500    18191521          SRIJAN DIXIT  cheque
# 7                   17500   181901346        ANUJ PRAJAPATI  online
# 8                   13000    18192337            SAIMA BHAT    cash
# 3                   10200   181901457         VISHESH SINGH    cash
#
#            Term        Date   Status
# 0             -           -        -
# 6       monthly  2018-07-31  pending
# 9   half-yearly  2018-07-31  pending
# 10  half-yearly  2018-07-31  pending
# 11  half-yearly  2018-07-31  pending
# 1       monthly  2018-07-31  pending
# 4       monthly  2018-07-31  pending
# 12      monthly  2018-07-31  pending
# 13      monthly  2018-07-31     paid
# 2       monthly  2018-07-31  pending
# 5       monthly  2018-07-31  pending
# 7       monthly  2018-07-31  pending
# 8       monthly  2018-07-31  pending
# 3       monthly  2018-07-31  pending

# %%
mlt.subplots(figsize=(10,7))
sns.countplot(x=D30_['Mode'],hue=D30_['Mode'], data=D30_).set_title("Tenant count Payment Mode wise")
#mlt.savefig('status_20180701_to_20180723.png')
mlt.show()

# %%
mlt.subplots(figsize=(10,9))
sns.countplot(x=D30_['Property Name'],hue=D30_['Property Name'], data=D30_).set_title("Tenant count property wise")
#mlt.savefig('status_20180701_to_20180723.png')
mlt.show()

# %%
mlt.subplots(figsize=(10,7))
sns.countplot(x=D30_['Mode'],hue=D30_['Term'], data=D30_).set_title("monthly and yearly count payment mode wise")
#mlt.savefig('status_20180701_to_20180723.png')
mlt.show()

# %%
mlt.subplots(figsize=(20,9))
sns.countplot(x=D30_['Property Name'],hue=D30_['Status'], data=D30_).set_title("status Property wise")
#mlt.savefig('status_20180701_to_20180723.png')
mlt.show()

# %%
mlt.subplots(figsize=(20,7))
sns.countplot(x=D30_['Tenant Code'],hue=D30_['Mode'], data=D30_).set_title("Payment Mode used buy tenant")
#mlt.savefig('status_20180701_to_20180723.png')
mlt.show()

# %%
mlt.subplots(figsize=(20,7))
sns.countplot(x=D30_['Tenant Code'],hue=D30_['Term'], data=D30_).set_title("Tenant term used")
#mlt.savefig('status_20180701_to_20180723.png')
mlt.show()
