# %%
import networkx as nx #Graphical persentation of unshorted data
import numpy as np #calculation lib
import pandas as pd #data Shoting Lib eg:series
import matplotlib.pyplot as mlt #for plot the data 
mlt.style.use('fivethirtyeight')
import seaborn as sns #statical data vertualisation 
import plotly.offline as py #plotly is a data_virtualisation 
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls

#check_out and ls will help in the to show files and folders

from subprocess import check_output
print(check_output(["ls"]).decode("utf8"))
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# 26_HMS_F.ipynb
# col
# collect_and_due_amount_20180701_to_20180723.png
# cratio_25_7.csv
# cratio_25_7.ipynb
# CRM27_.ipynb
# csv
# due_and_collect_amount Graph.png
# FeeReport-2018-07-25 06_05_42.csv
# hms_db.sql
# modes_tenants_until_21072018.png
# month_date_range.ipynb
# monthly_property_Report_test.ipynb
# month_report_notebook.ipynb
# Paid_Pending.png
# persent_mode_report.ipynb
# PF009_2_may.png
# PF009_may.png
# README.md
# report _25_07_2018.ipynb
# status_20180701_to_20180723.png
# table.html
# Untitled.ipynb

# %%
HMS27_ = pd.read_csv('csv/26_july.csv')
HMS27_
# Out:
#    \tProperty Name\tInvoice ID\tTXN ID\tCollected Amount\tTenant Code\tTenant Name\tMode\tTerm\tDate\tStatus
# 0   62\tPlacio Elite Homes\t2018PM007787\t2.414920...
# 1   41\tPlacio Admire Homes\t2018PM006808\t\t17500...
# 2   39\tPlacio Admire Homes\t2018PM006810\t\t17500...
# 3   46\tPlacio Elite Homes\t2018PM007803\t\t156000...
# 4   53\tPlacio Elite Homes\t2018PM007796\t\t144000...
# 5   36\tPlacio Pavillion\t2018PM008813\t\t137500.0...
# 6   49\tPlacio Elite Homes\t2018PM007800\t\t137500...
# 7   50\tPlacio Elite Homes\t2018PM007799\t\t135000...
# 8   51\tPlacio Elite Homes\t2018PM007798\t\t132000...
# 9   52\tPlacio Elite Homes\t2018PM007797\t\t132000...
# 10  35\tPlacio Pavillion\t2018PM008814\t\t120500.0...
# 11  19\tPlacio Prime Living\t2018PM003830\t\t12000...
# 12  61\tPlacio Elite Homes\t2018PM007788\t\t120000...
# 13  48\tPlacio Elite Homes\t2018PM007801\t\t120000...
# 14  63\tPlacio Elite Homes\t2018PM007786\t\t120000...
# 15  54\tPlacio Elite Homes\t2018PM007795\t\t120000...
# 16  13\tPlacio Home Care KO-17\t2018PM017836\t\t10...
# 17  14\tPlacio Home Care KO-11\t2018PM015835\t\t10...
# 18  37\tPlacio Pavillion\t2018PM008812\t\t100500.0...
# 19  60\tPlacio Elite Homes\t2018PM007789\t\t96000....
# 20  24\tPlacio Atlantis Homes\t2018PF007825\t\t960...
# 21  56\tPlacio Elite Homes\t2018PM007793\t\t96000....
# 22  47\tPlacio Elite Homes\t2018PM007802\t\t96000....
# 23  18\tPlacio The Grand Castle\t2018PM011831\t\t9...
# 24  17\tPlacio The Grand Castle\t2018PM011832\t\t9...
# 25  40\tPlacio Admire Homes\t2018PM006809\t\t87000...
# 26  38\tPlacio Admire Homes\t2018PM006811\t\t85000...
# 27  28\tPlacio Divya Homes\t2018PF006821\t\t84000....
# 28  42\tPlacio Venus\t2018PF004807\t\t74500.0\t181...
# 29  31\tPlacio Shresth Homes\t2018PF002818\t\t7200...
# ..                                                ...
# 35  59\tPlacio Elite Homes\t2018PM007790\t\t63000....
# 36  11\tPlacio Home Care KO-17\t2018PM017838\t\t58...
# 37  25\tPlacio Atlantis Homes\t2018PF007824\t\t540...
# 38  26\tPlacio Divya Homes\t2018PF006823\t\t53500....
# 39  7\tPlacio Home Care KO-17\t2018PM017842\t\t500...
# 40  12\tPlacio Home Care KO-17\t2018PM017837\t\t45...
# 41  23\tPlacio Atlantis Homes\t2018PF007826\t\t420...
# 42  16\tPlacio Castle\t2018PM012833\t\t42000.0\t18...
# 43  33\tPlacio Pavillion\t2018PM008816\t\t40000.0\...
# 44  64\tPlacio Imperial Homez\t2018PF012782\t\t392...
# 45  57\tPlacio Elite Homes\t2018PM007792\t\t38000....
# 46  45\tPlacio Venus\t2018PF004804\t\t36000.0\t181...
# 47  55\tPlacio Elite Homes\t2018PM007794\t\t33000....
# 48  27\tPlacio Divya Homes\t2018PF006822\t\t30000....
# 49  5\tPlacio Royal Living\t2018PM026846\tSBIN2181...
# 50  21\tPlacio Prime Living\t2018PM003828\t\t24500...
# 51  20\tPlacio Prime Living\t2018PM003829\t\t24500...
# 52  30\tPlacio Shresth Homes\t2018PF002819\t\t1550...
# 53  4\tPlacio Angel Paradise\t2018PFI01848\t\t7000...
# 54  0\tPlacio Elite Homes 2\t2018PF003866\t\t5500....
# 55  34\tPlacio Pavillion\t2018PM008815\t\t5500.0\t...
# 56  1\tPlacio Elite Homes 2\t2018PF003865\t\t5500....
# 57  22\tPlacio Prime Living\t2018PM003827\t\t5500....
# 58  15\tPlacio Castle\t2018PM012834\t\t5500.0\t181...
# 59  9\tPlacio Home Care KO-17\t2018PM017840\t\t550...
# 60  3\tPlacio Castle\t2018PM012863\t\t5500.0\t1819...
# 61  2\tPlacio Elite Homes 2\t2018PF003864\t\t5500....
# 62  32\tPlacio Shresth Homes\t2018PF002817\t\t5500...
# 63  6\tPlacio AK Mansion\t2018PMI03843\t\t500.0\t1...
# 64  44\tPlacio Venus\t2018PF004805\t\t\t181901330\...
#
# [65 rows x 1 columns]

# %%
D26_ = HMS27_.sort_values(by='Collected Amount' , ascending= False)
D26_
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-6feb69c2425f> in <module>()
# ----> 1 D26_ = HMS27_.sort_values(by='Collected Amount' , ascending= False)
#       2 D26_
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4416             by = by[0]
#    4417             k = self._get_label_or_level_values(by, axis=axis,
# -> 4418                                                 stacklevel=stacklevel)
#    4419
#    4420             if isinstance(ascending, (tuple, list)):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis, stacklevel)
#    1377             values = self.axes[axis].get_level_values(key)._values
#    1378         else:
# -> 1379             raise KeyError(key)
#    1380
#    1381         # Check for duplicates
#
# KeyError: 'Collected Amount'

# %%
mlt.subplots(figsize=(10,7))
sns.countplot(x=D26_['Mode'],hue=D26_['Mode'], data=D26_).set_title("Tenant count Payment Mode wise")
#mlt.savefig('status_20180701_to_20180723.png')
mlt.show()

# %%
mlt.subplots(figsize=(40,9))
sns.countplot(x=D26_['Property Name'],hue=D26_['Property Name'], data=D26_).set_title("Tenant count property wise")
#mlt.savefig('status_20180701_to_20180723.png')
mlt.show()

# %%
mlt.subplots(figsize=(20,7))
sns.countplot(x=D26_['Mode'],hue=D26_['Term'], data=D26_).set_title("monthly and yearly count payment mode wise")
#mlt.savefig('status_20180701_to_20180723.png')
mlt.show()

# %%
mlt.subplots(figsize=(46,9))
sns.countplot(x=D26_['Property Name'],hue=D26_['Collected Amount'], data=D26_).set_title("amount collected property wise")
#mlt.savefig('status_20180701_to_20180723.png')
mlt.show()

# %%
mlt.subplots(figsize=(50,9))
sns.countplot(x=D26_['Property Name'],hue=D26_['Status'], data=D26_).set_title("status Property wise")
#mlt.savefig('status_20180701_to_20180723.png')
mlt.show()

# %%
mlt.subplots(figsize=(80,7))
sns.countplot(x=D26_['Tenant Code'],hue=D26_['Mode'], data=D26_).set_title("Payment Mode used buy tenant")
#mlt.savefig('status_20180701_to_20180723.png')
mlt.show()

# %%
mlt.subplots(figsize=(80,7))
sns.countplot(x=D26_['Tenant Code'],hue=D26_['Term'], data=D26_).set_title("Tenant term used")
#mlt.savefig('status_20180701_to_20180723.png')
mlt.show()
