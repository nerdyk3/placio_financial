# %%
import networkx as nx #Graphical persentation of unshorted data
import numpy as np #calculation lib
import pandas as pd #data Shoting Lib eg:series
import matplotlib.pyplot as mlt #for plot the data 
mlt.style.use('fivethirtyeight')
import seaborn as sns #statical data vertualisation 
import plotly.offline as py #plotly is a data_virtualisation 
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls

#check_out and ls will help in the to show files and folders

from subprocess import check_output
print(check_output(["ls"]).decode("utf8"))
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# 01_Aug_HMS_F.ipynb
# 26_HMS_F.ipynb
# 27_HMS_F.ipynb
# 28_HMS_F.ipynb
# 29_HMS_F.ipynb
# 30_HMS_F.ipynb
# 31_HMS_F.ipynb
# col
# collect_and_due_amount_20180701_to_20180723.png
# cratio_25_7.csv
# cratio_25_7.ipynb
# CRM01_Aug.ipynb
# CRM02_Aug.ipynb
# CRM27_.ipynb
# CRM28_.ipynb
# CRM29_.ipynb
# CRM30_.ipynb
# CRM31_.ipynb
# csv
# due_and_collect_amount Graph.png
# FeeReport-2018-07-25 06_05_42.csv
# hms_db.sql
# kk
# modes_tenants_until_21072018.png
# month_date_range.ipynb
# monthly_property_Report_test.ipynb
# month_report_notebook.ipynb
# Paid_Pending.png
# persent_mode_report.ipynb
# PF009_2_may.png
# PF009_may.png
# README.md
# report _25_07_2018.ipynb
# status_20180701_to_20180723.png
# table.html
# test.csv
# Untitled.ipynb

# %%
CRM30_ = pd.read_csv("csv/CRM01_Aug.csv")
CRM30_
# Out:
#                              Property Name Property visit date  \
# 0                                      NaN           01-Aug-18
# 1                                      NaN           01-Aug-18
# 2                             Admire Homes           01-Aug-18
# 3                               Angel Town           01-Aug-18
# 4                                      NaN           01-Aug-18
# 5                                      NaN           01-Aug-18
# 6                                      NaN           01-Aug-18
# 7                              Divya Homes           01-Aug-18
# 8                                 GR Homes           01-Aug-18
# 9                                      NaN           01-Aug-18
# 10                    Half Penny Residency           01-Aug-18
# 11                                     NaN           01-Aug-18
# 12                          Imperial Homez           01-Aug-18
# 13                                     NaN           01-Aug-18
# 14                                JP House           01-Aug-18
# 15            Placio Ashoka Inn(Nirmal PG)           01-Aug-18
# 16   Placio Crystal Homez(Dinesh property)           01-Aug-18
# 17  Placio Exotic Living(BR accommodation)           01-Aug-18
# 18                                     NaN           01-Aug-18
# 19                                     NaN           01-Aug-18
# 20                       Placio Nightangle           01-Aug-18
# 21                                     NaN           01-Aug-18
# 22                        Placio Salvina 1           01-Aug-18
# 23                  Prestige Living (boys)           01-Aug-18
# 24                                RG Niwas           01-Aug-18
# 25                                     NaN           01-Aug-18
# 26                                     NaN           01-Aug-18
# 27                                   Venus           01-Aug-18
#
#           Contact Name        Mobile                              Email  \
# 0                    .    8777867534           daminisingh659@gmail.com
# 1                Sneha    6203755394                                NaN
# 2               Mahesh    9310360054                                NaN
# 3           prem shila  918218979926                                NaN
# 4                 sonu    8377013862         pgupta8377013862@gmail.com
# 5               garima    8929481533                                NaN
# 6                rohit    8475810399                                NaN
# 7   UMA SHANKAR SHARMA    9958240440                                NaN
# 8          Sonam Singh    7987280590                                NaN
# 9             Vanshika    9399102713                                NaN
# 10             abhinav    9837172294                                NaN
# 11            abhishek    9540302075                                NaN
# 12               priya    7007653674                                NaN
# 13      vishal dhandha    9814101136                                NaN
# 18      Neha Morya (Intern)
# 19           Uvais Khan CRM
# 20         Kuldeep Chouhaan
# 21   Ankita Lohani (Intern)
# 22               Princy CRM
# 23           Himanshu Joshi
# 24       Abhishek Bhati CRM
# 25   Ankita Lohani (Intern)
# 26      Komal Arya (Intern)
# 27   Ankita Lohani (Intern)

# %%
x = CRM30_['Property Region'].value_counts()
y = CRM30_['Property Region'].nunique()
print(x,"\n\nTotal Property Region:",y)
# Out:
# Laxmi Nagar        8
# South Campus       7
# Noida              4
# Indore             4
# Greater Noida      2
# DU North Campus    1
# Name: Property Region, dtype: int64
#
# Total Property Region: 6

# %%
x = CRM30_['Property Name'].value_counts()
y = CRM30_['Property Name'].nunique()
print(x,"\n\nTotal Property Name:",y)
# Out:
# JP House                                  1
# Admire Homes                              1
# Placio Salvina 1                          1
# Divya Homes                               1
# Angel Town                                1
# Venus                                     1
# Prestige Living (boys)                    1
# Placio Nightangle                         1
# GR Homes                                  1
# Placio Crystal Homez(Dinesh property)     1
# Imperial Homez                            1
# RG Niwas                                  1
# Half Penny Residency                      1
# Placio Ashoka Inn(Nirmal PG)              1
# Placio Exotic Living(BR accommodation)    1
# Name: Property Name, dtype: int64
#
# Total Property Name: 15

# %%
x = CRM30_['Email'].value_counts()
y = CRM30_['Email'].nunique()
print(x,"\n\nTotal Email:",y)
# Out:
# pallaviprincess.kumari@gmail.com     1
# ayushi2065@gmail.com                 1
# chauhankomal40@gmail.com             1
# pgupta8377013862@gmail.com           1
# Aditichauhan930@gmail.com            1
# daminisingh659@gmail.com             1
# taskmastercommunication@gmail.com    1
# pankajaskme@gmail.com                1
# Name: Email, dtype: int64
#
# Total Email: 8

# %%
CRM30_['Assigned to'].value_counts()
# Out:
# Ankita Lohani (Intern)     9
# Princy CRM                 6
# Komal Arya (Intern)        4
# Abhishek Bhati CRM         2
# Kuldeep Chouhaan           1
# Akshita Singh CRM          1
# Neha Morya (Intern)        1
# Uvais Khan CRM             1
# Himanshu Joshi             1
# Himanshu Negi CRM          1
# Devanshi Gupta (Intern)    1
# Name: Assigned to, dtype: int64

# %%
mlt.subplots(figsize=(15,9))
sns.countplot(x=CRM30_['Property Region'], hue= CRM30_['Property Region'], data = CRM30_).set_title("CRM report 31072018 Property_Region Wise")
mlt.plot()
# Out:
# []

# %%
mlt.subplots(figsize=(30,9))
sns.countplot(x=CRM30_['Assigned to'], hue= CRM30_['Assigned to'], data = CRM30_).set_title("CRM report 31072018 Assigned to")
mlt.plot()
# Out:
# []

# %%
mlt.subplots(figsize=(30,9))
sns.countplot(x=CRM30_['Assigned to'], hue= CRM30_['Property Region'], data = CRM30_).set_title("CRM report 29072018 Assigned to")
mlt.plot()
# Out:
# []
