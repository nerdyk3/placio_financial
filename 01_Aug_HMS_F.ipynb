# %%
import networkx as nx #Graphical persentation of unshorted data
import numpy as np #calculation lib
import pandas as pd #data Shoting Lib eg:series
import matplotlib.pyplot as mlt #for plot the data 
mlt.style.use('fivethirtyeight')
import seaborn as sns #statical data vertualisation 
import plotly.offline as py #plotly is a data_virtualisation 
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls

#check_out and ls will help in the to show files and folders

from subprocess import check_output
print(check_output(["ls"]).decode("utf8"))
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# 01_Aug_HMS_F.ipynb
# 26_HMS_F.ipynb
# 27_HMS_F.ipynb
# 28_HMS_F.ipynb
# 29_HMS_F.ipynb
# 30_HMS_F.ipynb
# 31_HMS_F.ipynb
# col
# collect_and_due_amount_20180701_to_20180723.png
# cratio_25_7.csv
# cratio_25_7.ipynb
# CRM01_Aug.ipynb
# CRM02_Aug.ipynb
# CRM27_.ipynb
# CRM28_.ipynb
# CRM29_.ipynb
# CRM30_.ipynb
# CRM31_.ipynb
# csv
# due_and_collect_amount Graph.png
# FeeReport-2018-07-25 06_05_42.csv
# hms_db.sql
# kk
# modes_tenants_until_21072018.png
# month_date_range.ipynb
# monthly_property_Report_test.ipynb
# month_report_notebook.ipynb
# Paid_Pending.png
# persent_mode_report.ipynb
# PF009_2_may.png
# PF009_may.png
# README.md
# report _25_07_2018.ipynb
# status_20180701_to_20180723.png
# table.html
# test.csv
# Untitled.ipynb

# %%
HMS30_ = pd.read_csv('csv/1_aug.csv')
HMS30_
# Out:
#             Property Name     Invoice ID            TXN ID  Collected Amount  \
# 0   Placio Imperial Homez  2018PF0121041               NaN             30000
# 1         Placio RG Niwas  2018PF0091040   IMPS00059802453              9000
# 2   Placio Angel Paradise  2018PFI011035               NaN              7000
# 3         Placio RG Niwas  2018PF0091033               NaN             18500
# 4         Placio RG Niwas  2018PF0091032               NaN             10000
# 5             Placio Lily  2018PF0101027  ALLAH18213527559             13500
# 6         Placio Pinnacle  2018PFL021026               NaN             15500
# 7         Placio Pinnacle  2018PFL021025               NaN             13500
# 8         Placio Pinnacle  2018PFL021024               NaN             14000
# 9   Placio Home Care SL02  2018PM0181023               NaN             45000
# 10  Placio Home Care SL02  2018PM0181022               NaN             96000
# 11  Placio Home Care SL02  2018PM0181021               NaN             72000
# 12  Placio Home Care SL02  2018PM0181018               NaN             52000
# 13            Placio Lily  2018PF0101016               NaN             21000
# 14  Placio Imperial Homez  2018PF0121014               NaN              5000
# 15  Placio Imperial Homez  2018PF0121013               NaN             31000
# 16  Placio Imperial Homez  2018PF0121012               NaN             31000
#
#     Tenant Code           Tenant Name    Mode         Term        Date  \
# 0      18192364       chitanshi singh    cash      monthly  2018-08-01
# 1      18191587       VARNIKA VASISTH  online      monthly  2018-08-01
# 2     181900738       SHIVANI PARIHAR    cash      monthly  2018-08-01
# 3      18192359          SUKRITI HANS    cash      monthly  2018-08-01
# 4      18192358        KANCHAN PRASAD    cash      monthly  2018-08-01
# 5     181900869          Simran Verma  online      monthly  2018-08-01
# 6      18191993    Ms. Akanksha singh    cash      monthly  2018-08-01
# 7      18192134           Somya singh    cash      monthly  2018-08-01
# 8      18192177         Srashty Gupta    cash      monthly  2018-08-01
# 9      18191834           Jais Dargan  cheque  half-yearly  2018-08-01
# 10     18191534       Nitanshu Sharma  cheque  half-yearly  2018-08-01
# 11    181901294  Yash Vardhan Agrawal  cheque  half-yearly  2018-08-01
# 12     18192003           Ayush gupta    cash  half-yearly  2018-08-01
# 13    181900573         SHIVALI SINGH    cash      monthly  2018-08-01
# 14     18192017         Archita Singh    cash      monthly  2018-08-01
# 15    181901376         Anjali Sharma    cash      monthly  2018-08-01
# 16     18191588         Sakshi Sharma    cash      monthly  2018-08-01
#
#      Status
# 0   pending
# 1   pending
# 2   pending
# 3   pending
# 4   pending
# 5      paid
# 6   pending
# 7   pending
# 8   pending
# 9   pending
# 10  pending
# 11  pending
# 12  pending
# 13  pending
# 14  pending
# 15  pending
# 16  pending

# %%
D30_ = HMS30_.sort_values(by='Collected Amount' , ascending= False)
D30_
# Out:
#             Property Name     Invoice ID            TXN ID  Collected Amount  \
# 10  Placio Home Care SL02  2018PM0181022               NaN             96000
# 11  Placio Home Care SL02  2018PM0181021               NaN             72000
# 12  Placio Home Care SL02  2018PM0181018               NaN             52000
# 9   Placio Home Care SL02  2018PM0181023               NaN             45000
# 16  Placio Imperial Homez  2018PF0121012               NaN             31000
# 15  Placio Imperial Homez  2018PF0121013               NaN             31000
# 0   Placio Imperial Homez  2018PF0121041               NaN             30000
# 13            Placio Lily  2018PF0101016               NaN             21000
# 3         Placio RG Niwas  2018PF0091033               NaN             18500
# 6         Placio Pinnacle  2018PFL021026               NaN             15500
# 8         Placio Pinnacle  2018PFL021024               NaN             14000
# 7         Placio Pinnacle  2018PFL021025               NaN             13500
# 5             Placio Lily  2018PF0101027  ALLAH18213527559             13500
# 4         Placio RG Niwas  2018PF0091032               NaN             10000
# 1         Placio RG Niwas  2018PF0091040   IMPS00059802453              9000
# 2   Placio Angel Paradise  2018PFI011035               NaN              7000
# 14  Placio Imperial Homez  2018PF0121014               NaN              5000
#
#     Tenant Code           Tenant Name    Mode         Term        Date  \
# 10     18191534       Nitanshu Sharma  cheque  half-yearly  2018-08-01
# 11    181901294  Yash Vardhan Agrawal  cheque  half-yearly  2018-08-01
# 12     18192003           Ayush gupta    cash  half-yearly  2018-08-01
# 9      18191834           Jais Dargan  cheque  half-yearly  2018-08-01
# 16     18191588         Sakshi Sharma    cash      monthly  2018-08-01
# 15    181901376         Anjali Sharma    cash      monthly  2018-08-01
# 0      18192364       chitanshi singh    cash      monthly  2018-08-01
# 13    181900573         SHIVALI SINGH    cash      monthly  2018-08-01
# 3      18192359          SUKRITI HANS    cash      monthly  2018-08-01
# 6      18191993    Ms. Akanksha singh    cash      monthly  2018-08-01
# 8      18192177         Srashty Gupta    cash      monthly  2018-08-01
# 7      18192134           Somya singh    cash      monthly  2018-08-01
# 5     181900869          Simran Verma  online      monthly  2018-08-01
# 4      18192358        KANCHAN PRASAD    cash      monthly  2018-08-01
# 1      18191587       VARNIKA VASISTH  online      monthly  2018-08-01
# 2     181900738       SHIVANI PARIHAR    cash      monthly  2018-08-01
# 14     18192017         Archita Singh    cash      monthly  2018-08-01
#
#      Status
# 10  pending
# 11  pending
# 12  pending
# 9   pending
# 16  pending
# 15  pending
# 0   pending
# 13  pending
# 3   pending
# 6   pending
# 8   pending
# 7   pending
# 5      paid
# 4   pending
# 1   pending
# 2   pending
# 14  pending

# %%
mlt.subplots(figsize=(10,7))
sns.countplot(x=D30_['Mode'],hue=D30_['Mode'], data=D30_).set_title("Tenant count Payment Mode wise")
#mlt.savefig('status_20180701_to_20180723.png')
mlt.show()

# %%
mlt.subplots(figsize=(20,9))
sns.countplot(x=D30_['Property Name'],hue=D30_['Property Name'], data=D30_).set_title("Tenant count property wise")
#mlt.savefig('status_20180701_to_20180723.png')
mlt.show()

# %%
mlt.subplots(figsize=(10,7))
sns.countplot(x=D30_['Mode'],hue=D30_['Term'], data=D30_).set_title("monthly and yearly count payment mode wise")
#mlt.savefig('status_20180701_to_20180723.png')
mlt.show()

# %%
mlt.subplots(figsize=(20,9))
sns.countplot(x=D30_['Property Name'],hue=D30_['Status'], data=D30_).set_title("status Property wise")
#mlt.savefig('status_20180701_to_20180723.png')
mlt.show()

# %%
mlt.subplots(figsize=(20,7))
sns.countplot(x=D30_['Tenant Code'],hue=D30_['Mode'], data=D30_).set_title("Payment Mode used buy tenant")
#mlt.savefig('status_20180701_to_20180723.png')
mlt.show()

# %%
mlt.subplots(figsize=(40,7))
sns.countplot(x=D30_['Tenant Code'],hue=D30_['Term'], data=D30_).set_title("Tenant term used")
#mlt.savefig('status_20180701_to_20180723.png')
mlt.show()
