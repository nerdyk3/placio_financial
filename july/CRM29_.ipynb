# %%
import networkx as nx #Graphical persentation of unshorted data
import numpy as np #calculation lib
import pandas as pd #data Shoting Lib eg:series
import matplotlib.pyplot as mlt #for plot the data 
mlt.style.use('fivethirtyeight')
import seaborn as sns #statical data vertualisation 
import plotly.offline as py #plotly is a data_virtualisation 
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls

#check_out and ls will help in the to show files and folders

from subprocess import check_output
print(check_output(["ls"]).decode("utf8"))
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# 26_HMS_F.ipynb
# 27_HMS_F.ipynb
# 28_HMS_F.ipynb
# col
# collect_and_due_amount_20180701_to_20180723.png
# cratio_25_7.csv
# cratio_25_7.ipynb
# CRM27_.ipynb
# CRM28_.ipynb
# CRM29_.ipynb
# csv
# due_and_collect_amount Graph.png
# FeeReport-2018-07-25 06_05_42.csv
# hms_db.sql
# kk
# modes_tenants_until_21072018.png
# month_date_range.ipynb
# monthly_property_Report_test.ipynb
# month_report_notebook.ipynb
# Paid_Pending.png
# persent_mode_report.ipynb
# PF009_2_may.png
# PF009_may.png
# README.md
# report _25_07_2018.ipynb
# status_20180701_to_20180723.png
# table.html
# Untitled.ipynb

# %%
CRM29_= pd.read_csv("csv/CRM29_.csv")
CRM29_
# Out:
#                              Property Name Property visit date  \
# 0                                      NaN           29-Jul-18
# 1                                      NaN           29-Jul-18
# 2                                      NaN           29-Jul-18
# 3                                      NaN           29-Jul-18
# 4                                      NaN           29-Jul-18
# 5                                      NaN           29-Jul-18
# 6                                      NaN           29-Jul-18
# 7                                      NaN           29-Jul-18
# 8                             A.K. Mansion           29-Jul-18
# 9                                      NaN           29-Jul-18
# 10                                     NaN           29-Jul-18
# 11                               Amy House           29-Jul-18
# 12                                     NaN           29-Jul-18
# 13                                  Apollo           29-Jul-18
# 14                                Atlantis           29-Jul-18
# 15                             Divya Homes           29-Jul-18
# 16                                GR Homes           29-Jul-18
# 17                    Half Penny Residency           29-Jul-18
# 18                               Home Care           29-Jul-18
# 19                          Imperial Homez           29-Jul-18
# 20                                     NaN           29-Jul-18
# 21                                     NaN           29-Jul-18
# 22            Placio Ashoka Inn(Nirmal PG)           29-Jul-18
# 23                                     NaN           29-Jul-18
# 24                                     NaN           29-Jul-18
# 25  Placio Exotic Living(BR accommodation)           29-Jul-18
# 26                                     NaN           29-Jul-18
# 27                                     NaN           29-Jul-18
# 28                                     NaN           29-Jul-18
# 29                             Placio Lily           29-Jul-18
# 30                                     NaN           29-Jul-18
# 31                       Placio Nightangle           29-Jul-18
# 32                   Placio Oasis 1( Boys)           29-Jul-18
# 33                    Placio Oasis 5(Boys)           29-Jul-18
# 34                 Placio Pinnacle (Girls)           29-Jul-18
# 35                         Placio Vinayaka           29-Jul-18
# 36                                     NaN           29-Jul-18
# 37                                     NaN           29-Jul-18
# 38                  Prestige Living (boys)           29-Jul-18
# 39                                RG Niwas           29-Jul-18
# 40                                     NaN           29-Jul-18
# 41                                     NaN           29-Jul-18
# 42                                     NaN           29-Jul-18
# 43                           Shresth Homes           29-Jul-18
#
#                   Contact Name        Mobile                           Email  \
# 0           Sumedh Shrivastava    8982191211     shrivastavasumedh@gmail.com
# 1                   Knowlarity    7338917513                             NaN
# 2                  wasim akram    8949202854         wasimshankhan@gmail.com
# 3                        Harsh    8285439697     harshagollamudi95@gmail.com
# 4                      Shishil  919027125842                             NaN
# 5                     harshita    8109248204      harshita.sen1992@gmail.com
# 6                 Akshay Verma    7705997734        akshay909.cool@gmail.com
# 7                  Vipin Yadav    9760693350                             NaN
# 8                 Sheikh Zahid    9131089255                             NaN
# 9                      Rajveer    8839333508                             NaN
# 10                    Abhishek    9753685776                             NaN
# 11                   Dilvendre    7988023976                             NaN
# 12                      Shrish    9696535040                             NaN
# 13                       Anmol    7975378424                             NaN
# 14             ayush chaudhary    9897251252                             NaN
# 15                      Shruti    8638484134                             NaN
# 16                       aarti  917905002513        aartigautam788@gmail.com
# 17                       vivek  919837014795                             NaN
# 18                        Aman    8368892416                             NaN
# 19  Shweta Khokhar /7011482793    9643779083      shwetakhokhar765@gmail.com
# 20                      simran    8101347055        princesssimmy5@gmail.com
# 21                    Shritish  918800654518                             NaN
# 22                 rai vikrant    9910778187                             NaN
# 23                       Gagan  918800236118                             NaN
# 24                    Mr Nihal  918638836627          nihakdey0314@gmail.com
# 25                       Astha    7217263394                             NaN
# 26                    Bhandari    7042141753  sirjanabhandari55.sb@gmail.com
# 27                      Kanika    7011788173                             NaN
# 28                        Neha  917870686965        guptaneha18jan@gmail.com
# 29                   Prity dey    8971603903            pdpritydey@gmail.com
# 30               Ranveer singh    9425006004                             NaN
# 31                     Vinayak  918080338382         nepalivinayak@gmail.com
# 32                       nasir    8077770561                             NaN
# 33                      pankaj  919557978918                             NaN
# 34                         Sid    9455815613                             NaN
# 35                       Ankit    7000451664                             NaN
# 36                    bs barde    8109629264                             NaN
# 37                      aditya    8770076783                             NaN
# 38                      Naajid    9412602776          naajidsarosh@gmail.com
# 39                       kajal    7523069103                             NaN
# 40                       Ankur  918319941637                             NaN
# 41                      rubina  919953481570            rubinaa092@gmail.com
# 42          Titikksha Chaudhry    9044706111    titikksha.chaudhry@gmail.com
# 43            abdul rub sayeed    8299411289                             NaN
#
#         Lead Stage  Property Region            Property Area  \
# 0   visit schedule              NaN                      NaN
# 1   visit schedule              NaN                      NaN
# 2   visit schedule              NaN                      NaN
# 3   visit schedule              NaN                      NaN
# 4   visit schedule              NaN                      NaN
# 5   visit schedule              NaN                      NaN
# 6   visit schedule              NaN                      NaN
# 7   visit schedule              NaN                      NaN
# 8   visit schedule           Indore             Khandwa Road
# 9   visit schedule           Indore             Khandwa Road
# 10  visit schedule           Indore             Khandwa Road
# 11  visit schedule            Noida                   Raipur
# 12  visit schedule            Noida                   Raipur
# 13  visit schedule            Noida                   Raipur
# 14  visit schedule            Noida                   Raipur
# 15  visit schedule            Noida                   Raipur
# 16  visit schedule           Indore              Vijay Nagar
# 17  visit schedule    Greater Noida           Knowledge Park
# 18  visit schedule            Noida                   Raipur
# 19  visit schedule     South Campus               Khirki Ext
# 20  visit schedule     South Campus               Khirki Ext
# 21  visit schedule     South Campus               Khirki Ext
# 22  visit schedule     South Campus  Freedom fighters colony
# 23  visit schedule     South Campus  Freedom fighters colony
# 24  visit schedule     South Campus  Freedom fighters colony
# 25  visit schedule     South Campus        Hari Nagar Ashram
# 26  visit schedule     South Campus        Hari Nagar Ashram
# 27  visit schedule     South Campus        Hari Nagar Ashram
# 28  visit schedule     South Campus        Hari Nagar Ashram
# 29  visit schedule  DU North Campus              Outram Lane
# 30  visit schedule  DU North Campus              Outram Lane
# 31  visit schedule           Indore              Vijay Nagar
# 32  visit schedule  DU North Campus              Kamla Nagar
# 33  visit schedule  DU North Campus              Kamla Nagar
# 34  visit schedule          Lucknow                  Lucknow
# 35  visit schedule           Indore             Khandwa Road
# 36  visit schedule           Indore             Khandwa Road
# 37  visit schedule           Indore             Khandwa Road
# 38  visit schedule            Noida                   Raipur
# 39  visit schedule      Laxmi Nagar              Laxmi Nagar
# 40  visit schedule      Laxmi Nagar              Laxmi Nagar
# 41  visit schedule      Laxmi Nagar              Laxmi Nagar
# 42  visit schedule      Laxmi Nagar              Laxmi Nagar
# 43  visit schedule            Noida                   Raipur
#
#                 Assigned to
# 0        Abhishek Bhati CRM
# 1              Deoraj Kumar
# 2         Himanshu Negi CRM
# 3         Himanshu Negi CRM
# 4         Himanshu Negi CRM
# 5   Devanshi Gupta (Intern)
# 6   Devanshi Gupta (Intern)
# 7        Abhishek Bhati CRM
# 8        Abhishek Bhati CRM
# 9     Mahendra Kumar Mishra
# 10           Uvais Khan CRM
# 11        Himanshu Negi CRM
# 12        Himanshu Negi CRM
# 13           Himanshu Joshi
# 14   Ankita Lohani (Intern)
# 15        Himanshu Negi CRM
# 16        Himanshu Negi CRM
# 17        Himanshu Negi CRM
# 18        Himanshu Negi CRM
# 19           Uvais Khan CRM
# 20      Komal Arya (Intern)
# 21        Himanshu Negi CRM
# 22      Neha Morya (Intern)
# 23        Himanshu Negi CRM
# 24           Uvais Khan CRM
# 25        Himanshu Negi CRM
# 26        Himanshu Negi CRM
# 27        Himanshu Negi CRM
# 28        Himanshu Negi CRM
# 29           Uvais Khan CRM
# 30        Himanshu Negi CRM
# 31           Uvais Khan CRM
# 32         Shilpi Singh CRM
# 33        Himanshu Negi CRM
# 34        Himanshu Negi CRM
# 35    Mahendra Kumar Mishra
# 36      Komal Arya (Intern)
# 37      Neha Morya (Intern)
# 38        Himanshu Negi CRM
# 39      Komal Arya (Intern)
# 40        Himanshu Negi CRM
# 41               Princy CRM
# 42           Uvais Khan CRM
# 43               Princy CRM

# %%
x = CRM29_['Property Region'].value_counts()
y = CRM29_['Property Region'].nunique()
print(x,"\n\nTotal Property Region:",y)
# Out:
# South Campus       10
# Indore              8
# Noida               8
# Laxmi Nagar         4
# DU North Campus     4
# Greater Noida       1
# Lucknow             1
# Name: Property Region, dtype: int64
#
# Total Property Region: 7

# %%
x = CRM29_['Property Name'].value_counts()
y = CRM29_['Property Name'].nunique()
print(x,"\n\nTotal Property Name:",y)
# Out:
# Half Penny Residency                      1
# Home Care                                 1
# GR Homes                                  1
# RG Niwas                                  1
# Placio Nightangle                         1
# A.K. Mansion                              1
# Placio Lily                               1
# Prestige Living (boys)                    1
# Placio Pinnacle (Girls)                   1
# Placio Vinayaka                           1
# Placio Oasis 5(Boys)                      1
# Amy House                                 1
# Placio Ashoka Inn(Nirmal PG)              1
# Shresth Homes                             1
# Atlantis                                  1
# Placio Oasis 1( Boys)                     1
# Divya Homes                               1
# Imperial Homez                            1
# Placio Exotic Living(BR accommodation)    1
# Apollo                                    1
# Name: Property Name, dtype: int64
#
# Total Property Name: 20

# %%
x = CRM29_['Email'].value_counts()
y = CRM29_['Email'].nunique()
print(x,"\n\nTotal Email:",y)
# Out:
# akshay909.cool@gmail.com          1
# nihakdey0314@gmail.com            1
# princesssimmy5@gmail.com          1
# shrivastavasumedh@gmail.com       1
# titikksha.chaudhry@gmail.com      1
# nepalivinayak@gmail.com           1
# rubinaa092@gmail.com              1
# harshagollamudi95@gmail.com       1
# pdpritydey@gmail.com              1
# aartigautam788@gmail.com          1
# shwetakhokhar765@gmail.com        1
# wasimshankhan@gmail.com           1
# harshita.sen1992@gmail.com        1
# naajidsarosh@gmail.com            1
# guptaneha18jan@gmail.com          1
# sirjanabhandari55.sb@gmail.com    1
# Name: Email, dtype: int64
#
# Total Email: 16

# %%
CRM29_['Assigned to'].value_counts()
# Out:
# Himanshu Negi CRM          20
# Uvais Khan CRM              6
# Komal Arya (Intern)         3
# Abhishek Bhati CRM          3
# Neha Morya (Intern)         2
# Princy CRM                  2
# Devanshi Gupta (Intern)     2
# Mahendra Kumar Mishra       2
# Deoraj Kumar                1
# Himanshu Joshi              1
# Shilpi Singh CRM            1
# Ankita Lohani (Intern)      1
# Name: Assigned to, dtype: int64

# %%
mlt.subplots(figsize=(15,9))
sns.countplot(x=CRM29_['Property Region'], hue= CRM29_['Property Region'], data = CRM29_).set_title("CRM report 29072018 Property_Region Wise")
mlt.plot()
# Out:
# []

# %%
mlt.subplots(figsize=(20,9))
sns.countplot(x=CRM29_['Assigned to'], hue= CRM29_['Assigned to'], data = CRM29_).set_title("CRM report 29072018 Assigned to")
mlt.plot()
# Out:
# []

# %%
mlt.subplots(figsize=(40,9))
sns.countplot(x=CRM29_['Assigned to'], hue= CRM29_['Property Region'], data = CRM29_).set_title("CRM report 29072018 Assigned to")
mlt.plot()
# Out:
# []
