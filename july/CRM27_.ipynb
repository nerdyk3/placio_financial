# %%
import networkx as nx #Graphical persentation of unshorted data
import numpy as np #calculation lib
import pandas as pd #data Shoting Lib eg:series
import matplotlib.pyplot as mlt #for plot the data 
mlt.style.use('fivethirtyeight')
import seaborn as sns #statical data vertualisation 
import plotly.offline as py #plotly is a data_virtualisation 
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls

#check_out and ls will help in the to show files and folders

from subprocess import check_output
print(check_output(["ls"]).decode("utf8"))
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# 26_HMS_F.ipynb
# 27_HMS_F.ipynb
# col
# collect_and_due_amount_20180701_to_20180723.png
# cratio_25_7.csv
# cratio_25_7.ipynb
# CRM27_.ipynb
# CRM28_.ipynb
# csv
# due_and_collect_amount Graph.png
# FeeReport-2018-07-25 06_05_42.csv
# hms_db.sql
# modes_tenants_until_21072018.png
# month_date_range.ipynb
# monthly_property_Report_test.ipynb
# month_report_notebook.ipynb
# Paid_Pending.png
# persent_mode_report.ipynb
# PF009_2_may.png
# PF009_may.png
# README.md
# report _25_07_2018.ipynb
# status_20180701_to_20180723.png
# table.html
# Untitled.ipynb

# %%
CRM27_= pd.read_csv("csv/CRM27_.csv")
CRM27_
# Out:
#                    Property Name Property visit date  \
# 0                            NaN           27-Jul-18
# 1                            NaN           27-Jul-18
# 2                            NaN           27-Jul-18
# 3                            NaN           27-Jul-18
# 4                      Amy House           27-Jul-18
# 5                       Atlantis           27-Jul-18
# 6                    Divya Homes           27-Jul-18
# 7                            NaN           27-Jul-18
# 8                     Elite Home           27-Jul-18
# 9                            NaN           27-Jul-18
# 10                           NaN           27-Jul-18
# 11                      GR Homes           27-Jul-18
# 12          Half Penny Residency           27-Jul-18
# 13                           NaN           27-Jul-18
# 14                     Home Care           27-Jul-18
# 15  Placio Ashoka Inn(Nirmal PG)           27-Jul-18
# 16                   Placio Lily           27-Jul-18
# ...

# %%
x = CRM27_['Property Region'].value_counts()
y = CRM27_['Property Region'].nunique()
print(x,"\n\nTotal Property Region:",y)
# Out:
# Noida              9
# DU North Campus    4
# Indore             4
# Greater Noida      2
# Laxmi Nagar        2
# South Campus       1
# Lucknow            1
# Name: Property Region, dtype: int64
#
# Total Property Region: 7

# %%
x = CRM27_['Property Name'].value_counts()
y = CRM27_['Property Name'].nunique()
print(x,"\n\nTotal Property Name:",y)
# Out:
# GR Homes                        1
# Elite Home                      1
# Atlantis                        1
# Home Care                       1
# Half Penny Residency            1
# Placio Marigold (Boys)          1
# Prestige Living (boys)          1
# Placio Oasis 2(Girls)           1
# Placio Ashoka Inn(Nirmal PG)    1
# Divya Homes                     1
# Placio Nightangle               1
# Placio Nirmal Residency         1
# RG Niwas                        1
# Placio Lily                     1
# Placio Precious( Girls)         1
# Amy House                       1
# Name: Property Name, dtype: int64
#
# Total Property Name: 16

# %%
x = CRM27_['Email'].value_counts()
y = CRM27_['Email'].nunique()
print(x,"\n\nTotal Email:",y)
# Out:
# chauhankomal40@gmail.com         1
# ayushichatterjee@gmail.com       1
# om45shankar@gmail.com            1
# santosh_palali@rediffmail.com    1
# nagrajsingh0251@gmail.com        1
# urgirlanki@gmail.com             1
# shreya.singh.1250@gmail.com      1
# jaindivyanshu005@gmail.com       1
# ns684789@gmail.com               1
# Name: Email, dtype: int64
#
# Total Email: 9

# %%
CRM27_['Assigned to'].value_counts()
# Out:
# Himanshu Negi CRM              6
# Ankita Lohani (Intern)         4
# Uvais Khan CRM                 3
# Abhishek Bhati CRM             3
# Devanshi Gupta (Intern)        2
# Komal Arya (Intern)            2
# Alaa (Intern)                  1
# Smriti Arora                   1
# Mahendra Kumar Mishra          1
# Bharat Bhooshan Vishwakarma    1
# Mayank Pratap Singh            1
# Yadvendra Singh                1
# Himanshu Joshi                 1
# Name: Assigned to, dtype: int64

# %%
mlt.subplots(figsize=(15,9))
sns.countplot(x=CRM27_['Property Region'], hue= CRM27_['Property Region'], data = CRM27_).set_title("CRM report 27072018 Property_Region Wise")
mlt.plot()
# Out:
# []

# %%
mlt.subplots(figsize=(40,9))
sns.countplot(x=CRM27_['Assigned to'], hue= CRM27_['Property Region'], data = CRM27_).set_title("CRM report 27072018 Assigned to")
mlt.plot()
# Out:
# []

# %%
mlt.subplots(figsize=(40,9))
sns.countplot(x=CRM27_['Assigned to'], hue= CRM27_['Assigned to'], data = CRM27_).set_title("CRM report 27072018 Assigned to")
mlt.plot()
# Out:
# []
