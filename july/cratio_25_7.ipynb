# %%
import networkx as nx #Graphical persentation of unshorted data
import numpy as np #calculation lib
import pandas as pd #data Shoting Lib eg:series
import matplotlib.pyplot as mlt #for plot the data 
mlt.style.use('fivethirtyeight')
import seaborn as sns #statical data vertualisation 
import plotly.offline as py #plotly is a data_virtualisation 
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls

#check_out and ls will help in the to show files and folders

from subprocess import check_output
print(check_output(["ls"]).decode("utf8"))
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# 26_HMS_F.ipynb
# col
# collect_and_due_amount_20180701_to_20180723.png
# cratio_25_7.csv
# cratio_25_7.ipynb
# CRM27_.ipynb
# csv
# due_and_collect_amount Graph.png
# FeeReport-2018-07-25 06_05_42.csv
# hms_db.sql
# modes_tenants_until_21072018.png
# month_date_range.ipynb
# monthly_property_Report_test.ipynb
# month_report_notebook.ipynb
# Paid_Pending.png
# persent_mode_report.ipynb
# PF009_2_may.png
# PF009_may.png
# README.md
# report _25_07_2018.ipynb
# status_20180701_to_20180723.png
# table.html
# Untitled.ipynb

# %%
cratio_25_7 = pd.read_csv('cratio_25_7.csv')
cratio_25_7
# Out:
#                Property Name Property visit date            Contact Name  \
# 0                        NaN           25-Jul-18             Jyoti singh
# 1                        NaN           25-Jul-18              knowlarity
# 2                        NaN           25-Jul-18                       .
# 3                        NaN           25-Jul-18                  Ankita
# 4                        NaN           25-Jul-18                 Sourabh
# 5                        NaN           25-Jul-18         Abhinav jhariya
# 6                        NaN           25-Jul-18                  aizaaz
# 7                        NaN           25-Jul-18           Tamanna Yadav
# 8                   GR Homes           25-Jul-18              k p ranjan
# 9                        NaN           25-Jul-18            Rashi pandit
# 10                       NaN           25-Jul-18                  Nooman
# 11                       NaN           25-Jul-18                  apurva
# ...

# %%
cratio_25_7['Property_Region'].value_counts()
# Out:
# Indore             8
# non                7
# South Campus       7
# DU North Campus    3
# Noida              3
# Lucknow            1
# Laxmi Nagar        1
# Greater Noida      1
# Name: Property_Region, dtype: int64

# %%
mlt.subplots(figsize=(15,9))
sns.countplot(x=cratio_25_7['Property_Region'], hue= cratio_25_7['Property_Region'], data = cratio_25_7).set_title("CRM report 25072018 Property_Region Wise")
mlt.plot()
# Out:
# []

# %%
mlt.subplots(figsize=(22,16))
sns.countplot(x=cratio_25_7['Assigned to'], hue= cratio_25_7['Assigned to'], data = cratio_25_7).set_title("CRM report 25072018 no of lead assigned")
mlt.plot()
# Out:
# []

# %%
cratio_25_7.keys()
# Out:
# Index(['Property Name', 'Property visit date', 'Contact Name', 'Mobile',
#        'Email', 'Lead_Stage', 'Property_Region', 'Property Area',
#        'Assigned to'],
#       dtype='object')
