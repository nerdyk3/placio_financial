# %%
import networkx as nx #Graphical persentation of unshorted data
import numpy as np #calculation lib
import pandas as pd #data Shoting Lib eg:series
import matplotlib.pyplot as mlt #for plot the data 
mlt.style.use('fivethirtyeight')
import seaborn as sns #statical data vertualisation 
import plotly.offline as py #plotly is a data_virtualisation 
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls

#check_out and ls will help in the to show files and folders

from subprocess import check_output
print(check_output(["ls"]).decode("utf8"))
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# 01_Aug_HMS_F.ipynb
# 02_Aug_HMS_F.ipynb
# 03_Aug_HMS_F.ipynb
# 04_Aug_HMS_F.ipynb
# 05_Aug_HMS_F.ipynb
# 06_Aug_HMS_F.ipynb
# col
# collect_and_due_amount_20180701_to_20180723.png
# converted_3_aug.ipynb
# CRM01_Aug.ipynb
# CRM02_Aug.ipynb
# CRM03_Aug.ipynb
# CRM04_Aug.ipynb
# CRM05_Aug.ipynb
# CRM06_Aug.ipynb
# csv
# due_and_collect_amount Graph.png
# FeeReport-2018-07-25 06_05_42.csv
# hms_db.sql
# july
# kk
# modes_tenants_until_21072018.png
# online6.ipynb
# Paid_Pending.png
# PF009_2_may.png
# PF009_may.png
# README.md
# status_20180701_to_20180723.png
# table.html
# test.csv
# Untitled.ipynb

# %%
ONLI = pd.read_csv("csv/online_6_aug.csv")
ONLI
# Out:
#     S.no.                  Name  Contact No.             Area  \
# 0       1          Pawan Somani   9810677622      South Delhi
# 1       2               Prakhar   8630742689  Noida  (Sec-41)
# 2       3             Sid Singh   8318933149      North Delhi
# 3       4      Divyanshi Pandey   9415107247      North Delhi
# 4       5             Riya Lath   9686534469             None
# 5       6               Varnika   6261302860           Indore
# 6       7                 Rahul   8448661170    Greater Noida
# 7       8            Chitranshi   9807002191        Ghaziabad
# 8       9        Harshit Tiwari   8736829166  Cannaught Place
# 9      10         Navneet Kumar   9557274999  Cannaught Place
# 10     11       Bhartendu Vimal   8521007044      Laxmi Nagar
# 11     12                Saurav   9315895073              NaN
# 12     13              shreysee   8787216090          Lucknow
# 13     14        Durgesh Shukla   8400216136          Lucknow
# ...

# %%
x = ONLI['Area'].value_counts()
y = ONLI['Area'].nunique()
print(x,"\n\nTotal Area:",y)
# Out:
# None               5
# North Delhi        2
# Lucknow            2
# Cannaught Place    2
# Greater Noida      1
# Noida  (Sec-41)    1
# South Delhi        1
# Ghaziabad          1
# Indore             1
# Laxmi Nagar        1
# Name: Area, dtype: int64
#
# Total Area: 10

# %%
x = ONLI['Property'].value_counts()
y = ONLI['Property'].nunique()
print(x,"\n\nTotal Property:",y)
# Out:
# Half Penny Residency    1
# Placio oasis1           1
# Placio Birdhouse1       1
# GR Homes                1
# Placio JP House         1
# Name: Property, dtype: int64
#
# Total Property: 5

# %%
x = ONLI['Assigned To'].value_counts()
y = ONLI['Assigned To'].nunique()
print(x,"\n\nTotal Assigned To:",y)
# Out:
# Princy CRM           11
# Uvais Khan CRM        3
# Abhishek CRM          2
# Himanshu Negi CRM     1
# Shilpi CRM            1
# Name: Assigned To, dtype: int64
#
# Total Assigned To: 5

# %%
x = ONLI['Email'].value_counts()
y = ONLI['Email'].nunique()
print(x,"\n\nTotal Email:",y)
# Out:
# n/a                                   14
# gouravagrawal12345.dabbu@gmail.com     1
# shreyseeojha@gmail.com                 1
# navneet.fms.gkv@gmail.com              1
# Name: Email, dtype: int64
#
# Total Email: 4

# %%
mlt.subplots(figsize=(15,9))
sns.countplot(x=ONLI['Area'], hue= ONLI['Area'], data = ONLI).set_title("TwAK report:Property_Region Wise")
mlt.show()

# %%
mlt.subplots(figsize=(15,9))
sns.countplot(x=ONLI['Assigned To'], hue= ONLI['Assigned To'], data = ONLI).set_title("TwAK report:Property_Region Wise")
mlt.show()

# %%
mlt.subplots(figsize=(30,9))
sns.countplot(x=ONLI['Assigned To'], hue= ONLI['Area'], data = ONLI).set_title("CRM report 29072018 Assigned to")
mlt.show()

# %%
mlt.subplots(figsize=(50,9))
sns.countplot(x=ONLI['Remarks'], hue= ONLI['Remarks'], data = ONLI).set_title("CRM report 29072018 Assigned to")
mlt.show()
