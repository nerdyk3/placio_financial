# %%
import networkx as nx #Graphical persentation of unshorted data
import numpy as np #calculation lib
import pandas as pd #data Shoting Lib eg:series
import matplotlib.pyplot as mlt #for plot the data 
mlt.style.use('fivethirtyeight')
import seaborn as sns #statical data vertualisation 
import plotly.offline as py #plotly is a data_virtualisation 
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls

#check_out and ls will help in the to show files and folders

from subprocess import check_output
print(check_output(["ls"]).decode("utf8"))
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# 01_Aug_HMS_F.ipynb
# 02_Aug_HMS_F.ipynb
# 03_Aug_HMS_F.ipynb
# 04_Aug_HMS_F.ipynb
# 05_Aug_HMS_F.ipynb
# 06_Aug_HMS_F.ipynb
# col
# collect_and_due_amount_20180701_to_20180723.png
# converted_3_aug.ipynb
# CRM01_Aug.ipynb
# CRM02_Aug.ipynb
# CRM03_Aug.ipynb
# CRM04_Aug.ipynb
# CRM05_Aug.ipynb
# CRM06_Aug.ipynb
# csv
# due_and_collect_amount Graph.png
# FeeReport-2018-07-25 06_05_42.csv
# hms_db.sql
# july
# kk
# modes_tenants_until_21072018.png
# Paid_Pending.png
# PF009_2_may.png
# PF009_may.png
# README.md
# status_20180701_to_20180723.png
# table.html
# test.csv
# Untitled.ipynb

# %%
HMS30_ = pd.read_csv('csv/6_aug.csv')
HMS30_
# Out:
#             Property Name     Invoice ID            TXN ID  Collected Amount  \
# 0         Placio RG Niwas  2018PF0091189               NaN              8200
# 1         Placio RG Niwas  2018PF0091188               NaN              7500
# 2         Placio RG Niwas  2018PF0091187               NaN              7000
# 3         Placio RG Niwas  2018PF0091186               NaN              7000
# 4         Placio RG Niwas  2018PF0091185               NaN              7000
# 5         Placio RG Niwas  2018PF0091184               NaN              5000
# 6   Placio Imperial Homez  2018PF0121181               NaN             11000
# 7   Placio Imperial Homez  2018PF0121180            896577             11500
# 8   Placio Imperial Homez  2018PF0121179               NaN             11500
# 9           Placio Orchid  2018PF0131166  N218180602460845             16000
# 10      Placio Ashoka Inn  2018PM0241165          18321900             10000
# 11        Placio RG Niwas  2018PF0091034               NaN             17917
#
#     Tenant Code        Tenant Name    Mode     Term        Date   Status
# 0      18192126       JUHI AGARWAL    cash  monthly  2018-08-06  pending
# 1      18191742        TANVI TYAGI    cash  monthly  2018-08-06  pending
# 2     181901388       ASHI AGARWAL    cash  monthly  2018-08-06  pending
# 3     181901262    ROSHNI VARSHNEY    cash  monthly  2018-08-06  pending
# 4     181901258      YASHI AGARWAL    cash  monthly  2018-08-06  pending
# 5      18192481           SAIPRIYA    cash  monthly  2018-08-06  pending
# 6     181900682        Meenu Singh    cash  monthly  2018-08-06  pending
# 7      18192464      sonali sharma  cheque  monthly  2018-08-06  pending
# 8      18192025   asita srivastava    cash  monthly  2018-08-06  pending
# 9     181901314              Mansi  online  monthly  2018-08-06  pending
# 10    181901290       RISHAB GUPTA   paytm  monthly  2018-08-06  pending
# 11    181901351  PRIYANSHI AGARWAL    cash  monthly  2018-08-06  pending

# %%
D30_ = HMS30_.sort_values(by='Collected Amount' , ascending= False)
D30_
# Out:
#             Property Name     Invoice ID            TXN ID  Collected Amount  \
# 11        Placio RG Niwas  2018PF0091034               NaN             17917
# 9           Placio Orchid  2018PF0131166  N218180602460845             16000
# 7   Placio Imperial Homez  2018PF0121180            896577             11500
# 8   Placio Imperial Homez  2018PF0121179               NaN             11500
# 6   Placio Imperial Homez  2018PF0121181               NaN             11000
# 10      Placio Ashoka Inn  2018PM0241165          18321900             10000
# 0         Placio RG Niwas  2018PF0091189               NaN              8200
# 1         Placio RG Niwas  2018PF0091188               NaN              7500
# 2         Placio RG Niwas  2018PF0091187               NaN              7000
# 3         Placio RG Niwas  2018PF0091186               NaN              7000
# 4         Placio RG Niwas  2018PF0091185               NaN              7000
# 5         Placio RG Niwas  2018PF0091184               NaN              5000
#
#     Tenant Code        Tenant Name    Mode     Term        Date   Status
# 11    181901351  PRIYANSHI AGARWAL    cash  monthly  2018-08-06  pending
# 9     181901314              Mansi  online  monthly  2018-08-06  pending
# 7      18192464      sonali sharma  cheque  monthly  2018-08-06  pending
# 8      18192025   asita srivastava    cash  monthly  2018-08-06  pending
# 6     181900682        Meenu Singh    cash  monthly  2018-08-06  pending
# 10    181901290       RISHAB GUPTA   paytm  monthly  2018-08-06  pending
# 0      18192126       JUHI AGARWAL    cash  monthly  2018-08-06  pending
# 1      18191742        TANVI TYAGI    cash  monthly  2018-08-06  pending
# 2     181901388       ASHI AGARWAL    cash  monthly  2018-08-06  pending
# 3     181901262    ROSHNI VARSHNEY    cash  monthly  2018-08-06  pending
# 4     181901258      YASHI AGARWAL    cash  monthly  2018-08-06  pending
# 5      18192481           SAIPRIYA    cash  monthly  2018-08-06  pending

# %%
mlt.subplots(figsize=(10,7))
sns.countplot(x=D30_['Mode'],hue=D30_['Mode'], data=D30_).set_title("Tenant count Payment Mode wise")
#mlt.savefig('status_20180701_to_20180723.png')
mlt.show()

# %%
mlt.subplots(figsize=(20,9))
sns.countplot(x=D30_['Property Name'],hue=D30_['Property Name'], data=D30_).set_title("Tenant count property wise")
#mlt.savefig('status_20180701_to_20180723.png')
mlt.show()

# %%
mlt.subplots(figsize=(8,7))
sns.countplot(x=D30_['Mode'],hue=D30_['Term'], data=D30_).set_title("monthly and yearly count payment mode wise")
#mlt.savefig('status_20180701_to_20180723.png')
mlt.show()

# %%
mlt.subplots(figsize=(20,9))
sns.countplot(x=D30_['Property Name'],hue=D30_['Status'], data=D30_).set_title("status Property wise")
#mlt.savefig('status_20180701_to_20180723.png')
mlt.show()

# %%
mlt.subplots(figsize=(30,7))
sns.countplot(x=D30_['Tenant Code'],hue=D30_['Mode'], data=D30_).set_title("Payment Mode used buy tenant")
#mlt.savefig('status_20180701_to_20180723.png')
mlt.show()

# %%
mlt.subplots(figsize=(40,7))
sns.countplot(x=D30_['Tenant Code'],hue=D30_['Term'], data=D30_).set_title("Tenant term used")
#mlt.savefig('status_20180701_to_20180723.png')
mlt.show()
