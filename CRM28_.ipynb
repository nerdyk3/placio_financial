# %%
import networkx as nx #Graphical persentation of unshorted data
import numpy as np #calculation lib
import pandas as pd #data Shoting Lib eg:series
import matplotlib.pyplot as mlt #for plot the data 
mlt.style.use('fivethirtyeight')
import seaborn as sns #statical data vertualisation 
import plotly.offline as py #plotly is a data_virtualisation 
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls

#check_out and ls will help in the to show files and folders

from subprocess import check_output
print(check_output(["ls"]).decode("utf8"))
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# 26_HMS_F.ipynb
# 27_HMS_F.ipynb
# col
# collect_and_due_amount_20180701_to_20180723.png
# cratio_25_7.csv
# cratio_25_7.ipynb
# CRM27_.ipynb
# CRM28_.ipynb
# csv
# due_and_collect_amount Graph.png
# FeeReport-2018-07-25 06_05_42.csv
# hms_db.sql
# modes_tenants_until_21072018.png
# month_date_range.ipynb
# monthly_property_Report_test.ipynb
# month_report_notebook.ipynb
# Paid_Pending.png
# persent_mode_report.ipynb
# PF009_2_may.png
# PF009_may.png
# README.md
# report _25_07_2018.ipynb
# status_20180701_to_20180723.png
# table.html
# Untitled.ipynb

# %%
CRM28_= pd.read_csv("csv/CRM28_.csv")
CRM28_
# Out:
#                              Property Name Property visit date  \
# 0                                      NaN           28-Jul-18
# 1                                      NaN           28-Jul-18
# 2                                      NaN           28-Jul-18
# 3                                      NaN           28-Jul-18
# 4                                      NaN           28-Jul-18
# 5                                      NaN           28-Jul-18
# 6                             Admire Homes           28-Jul-18
# 7                              Divya Homes           28-Jul-18
# 8                                      NaN           28-Jul-18
# 9                               Elite Home           28-Jul-18
# 10                                GR Homes           28-Jul-18
# 11                                     NaN           28-Jul-18
# 12                    Half Penny Residency           28-Jul-18
# 13                          Imperial Homez           28-Jul-18
# ...

# %%
x = CRM28_['Property Region'].value_counts()
y = CRM28_['Property Region'].nunique()
print(x,"\n\nTotal Property Region:",y)
# Out:
# South Campus       16
# Indore             12
# Noida              10
# Laxmi Nagar         3
# DU North Campus     3
# Lucknow             1
# Greater Noida       1
# Name: Property Region, dtype: int64
#
# Total Property Region: 7

# %%
x = CRM28_['Property Name'].value_counts()
y = CRM28_['Property Name'].nunique()
print(x,"\n\nTotal Property Name:",y)
# Out:
# Prestige Living (boys)                    1
# Placio Ashoka Inn(Nirmal PG)              1
# Venus                                     1
# Imperial Homez                            1
# RG Niwas                                  1
# Placio Oasis 5(Boys)                      1
# Placio Nightangle                         1
# Divya Homes                               1
# Admire Homes                              1
# Placio Lily                               1
# Elite Home                                1
# Placio Jasmine                            1
# Half Penny Residency                      1
# Pavilion                                  1
# Placio Pinnacle (Girls)                   1
# Placio Exotic Living(BR accommodation)    1
# Placio Crystal Homez(Dinesh property)     1
# GR Homes                                  1
# Name: Property Name, dtype: int64
#
# Total Property Name: 18

# %%
x = CRM28_['Email'].value_counts()
y = CRM28_['Email'].nunique()
print(x,"\n\nTotal Email:",y)
# Out:
# tripathianil64@gmail.com         1
# nikkystarz@gmail.com             1
# anushreeagarwal97@yahoo.com      1
# Raisatyam204@gmail.com           1
# lovearora7988@gmail.com          1
# ybib@rediffmail.com              1
# upasanadeb11@gmail.com           1
# grajawat655@gmail.com            1
# devyani.mehrotra11@gmail.com     1
# myonlineshoppingid7@gmail.com    1
# ns684789@gmail.com               1
# mainkarajput9@gmail.com          1
# alok1.bhandari@gmail.com         1
# shivish92@yahoo.in               1
# monika.gupta2692@gmail.com       1
# anmolv999@gmail.co               1
# classydeepanjali55@gmail.com     1
# kaushikgon@gmail.com             1
# joseph.jinsu7@gmail.com          1
# saumyagupta08041996@gmail.com    1
# rshankarac3@gmail.com            1
# alishabari00@gmail.com           1
# swt.shraddha@gmail.com           1
# Name: Email, dtype: int64
#
# Total Email: 23

# %%
CRM28_['Assigned to'].value_counts()
# Out:
# Abhishek Bhati CRM         10
# Komal Arya (Intern)        10
# Ankita Lohani (Intern)      8
# Kuldeep Chouhaan            5
# Uvais Khan CRM              4
# Neha Morya (Intern)         3
# Akshita Singh CRM           3
# Bushra Iqbal(intern)        3
# Devanshi Gupta (Intern)     2
# Rakesh Mishra               1
# Deoraj Kumar                1
# Princy CRM                  1
# Mayank Pratap Singh         1
# Name: Assigned to, dtype: int64

# %%
mlt.subplots(figsize=(15,9))
sns.countplot(x=CRM28_['Property Region'], hue= CRM28_['Property Region'], data = CRM28_).set_title("CRM report 28072018 Property_Region Wise")
mlt.plot()
# Out:
# []

# %%
mlt.subplots(figsize=(30,9))
sns.countplot(x=CRM28_['Assigned to'], hue= CRM28_['Assigned to'], data = CRM28_).set_title("CRM report 28072018 Assigned to")
mlt.plot()
# Out:
# []

# %%
mlt.subplots(figsize=(40,9))
sns.countplot(x=CRM28_['Assigned to'], hue= CRM28_['Property Region'], data = CRM28_).set_title("CRM report 27072018 Assigned to")
mlt.plot()
# Out:
# []
